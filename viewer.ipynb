# %%
import pickle
import pandas as pd
from pathlib import Path
import json

# Cargar pickle
with open('checkpoints/apps_dict-ckpt-fin.p', 'rb') as f:
    apps_dict = pickle.load(f)

# Convertir a lista de diccionarios aplanados
games_list = []
for appid, game_data in apps_dict.items():
    game = {
        'appid': appid,
        'name': game_data.get('name'),
        'type': game_data.get('type'),
        'is_free': game_data.get('is_free'),
        'genres': ', '.join([g['description'] for g in game_data.get('genres', [])]),
        'price': game_data.get('price_overview', {}).get('final', 0) / 100 if game_data.get('price_overview') else 0,
        'metacritic_score': game_data.get('metacritic', {}).get('score') if game_data.get('metacritic') else None,
        'header_image': game_data.get('header_image'),
        'recomendations': game_data.get('recommendations', {}).get('total', 0) if game_data.get('recommendations') else 0,

    }
    games_list.append(game)

df = pd.DataFrame(games_list)
df.to_csv('steam_games.csv', index=False, encoding='utf-8')
print(f"✓ Guardados {len(df)} juegos en steam_games.csv")
# Out:
# ✓ Guardados 32500 juegos en steam_games.csv

# %%
df
# Out:
#          appid                                    name  type  is_free  \
# 0      2621440                 Infinity Castle Dungeon  game    False
# 1      1048580             Terje Haakonsen's Powder VR  game    False
# 2      2097160                         Monster Mystery  game     True
# 3           10                          Counter-Strike  game    False
# 4      3145740                             VRider SBK™  game    False
# ...        ...                                     ...   ...      ...
# 32495  3787430                    Money Theft 2: Heist  game    False
# 32496  2214570                       Adventures of Red  game    False
# 32497  2738860                       Seductive Shadows  game    False
# 32498  3263150                    Anna's Summer Splash  game    False
# 32499  1166000  Battleships and Carriers - Pacific War  game    False
#
#                                                   genres  price  \
# 0                       Action, Adventure, Casual, Indie   3.99
# 1      Casual, Indie, Racing, Simulation, Sports, Ear...  16.79
# 2                            Action, Free To Play, Indie   0.00
# 3                                                 Action   8.19
# 4                      Indie, Racing, Simulation, Sports  28.99
# ...                                                  ...    ...
# 32495                           Action, Adventure, Indie   0.67
# 32496                           Adventure, Casual, Indie   3.99
# 32497             Adventure, Casual, Indie, Early Access  11.79
# 32498                   Action, Adventure, Casual, Indie  17.49
# 32499                       Casual, Simulation, Strategy  11.95
#
#        metacritic_score                                       header_image  \
# 0                   NaN  https://shared.akamai.steamstatic.com/store_it...
# 1                   NaN  https://shared.akamai.steamstatic.com/store_it...
# 2                   NaN  https://shared.akamai.steamstatic.com/store_it...
# 3                  88.0  https://shared.akamai.steamstatic.com/store_it...
# 4                   NaN  https://shared.akamai.steamstatic.com/store_it...
# ...                 ...                                                ...
# 32495               NaN  https://shared.akamai.steamstatic.com/store_it...
# 32496               NaN  https://shared.akamai.steamstatic.com/store_it...
# 32497               NaN  https://shared.akamai.steamstatic.com/store_it...
# 32498               NaN  https://shared.akamai.steamstatic.com/store_it...
# 32499               NaN  https://shared.akamai.steamstatic.com/store_it...
#
#        recomendations
# 0                   0
# 1                   0
# 2                   0
# 3              164254
# 4                   0
# ...               ...
# 32495               0
# 32496               0
# 32497               0
# 32498               0
# 32499               0
#
# [32500 rows x 9 columns]
