# %%
import requests
import time
import sqlite3

# %%
def fetch_and_save_data():
    base_url = "https://steamspy.com/api.php?request=all&page="
    page = 0
    
    # Conectar a la base de datos SQLite (se crea si no existe)
    conn = sqlite3.connect('steam_data.db')
    cursor = conn.cursor()
    
    # Variable para controlar si ya creamos la tabla
    table_created = False

    while True:
        print(f"Obteniendo página {page}...")
        response = requests.get(base_url + str(page))
        
        if response.status_code != 200:
            print(f"Error: Código de estado {response.status_code}")
            break
        
        data = response.json()
        if not data or len(data) == 0:
            print("No hay más datos disponibles")
            break
        
        # Crear la tabla con la primera página de datos
        if not table_created:
            # Obtener las columnas del primer juego
            first_game = list(data.values())[0]
            columns = first_game.keys()
            
            # Crear la tabla
            columns_def = ', '.join([f'"{col}" TEXT' for col in columns])
            cursor.execute(f'CREATE TABLE IF NOT EXISTS steam_games ({columns_def})')
            table_created = True
            print("Tabla creada exitosamente")
        
        # Insertar los datos
        for game_id, game_data in data.items():
            columns = list(game_data.keys())
            placeholders = ', '.join(['?' for _ in columns]) 
            columns_str = ', '.join([f'"{col}"' for col in columns])
            values = [str(game_data[col]) for col in columns]
            
            cursor.execute(f'INSERT INTO steam_games ({columns_str}) VALUES ({placeholders})', values)
        
        conn.commit()
        print(f"Página {page} guardada exitosamente ({len(data)} juegos)")
        
        page += 1
        
        # Esperar 70 segundos antes de la siguiente solicitud
        time.sleep(70)
    
    # Cerrar la conexión
    conn.close()
    print(f"Recolección de datos completada. Total de páginas: {page}")

fetch_and_save_data()
# Out:
# Obteniendo página 0...
# Tabla creada exitosamente
# Página 0 guardada exitosamente (1000 juegos)
# Obteniendo página 1...
# Página 1 guardada exitosamente (1000 juegos)
# Obteniendo página 1...
# Página 1 guardada exitosamente (1000 juegos)
# Obteniendo página 2...
# Página 2 guardada exitosamente (1000 juegos)
# Obteniendo página 2...
# Página 2 guardada exitosamente (1000 juegos)
# Obteniendo página 3...
# Página 3 guardada exitosamente (1000 juegos)
# Obteniendo página 3...
# Página 3 guardada exitosamente (1000 juegos)
# Obteniendo página 4...
# Página 4 guardada exitosamente (1000 juegos)
# Obteniendo página 4...
# Página 4 guardada exitosamente (1000 juegos)
# Obteniendo página 5...
# Página 5 guardada exitosamente (1000 juegos)
# Obteniendo página 5...
# Página 5 guardada exitosamente (1000 juegos)
# Obteniendo página 6...
# Página 6 guardada exitosamente (1000 juegos)
# Obteniendo página 6...
# Página 6 guardada exitosamente (1000 juegos)
# Obteniendo página 7...
# Página 7 guardada exitosamente (1000 juegos)
# Obteniendo página 7...
# Página 7 guardada exitosamente (1000 juegos)
# Obteniendo página 8...
# Página 8 guardada exitosamente (1000 juegos)
# Obteniendo página 8...
# Página 8 guardada exitosamente (1000 juegos)
# Obteniendo página 9...
# Página 9 guardada exitosamente (1000 juegos)
# Obteniendo página 9...
# Página 9 guardada exitosamente (1000 juegos)
# Obteniendo página 10...
# Página 10 guardada exitosamente (1000 juegos)
# Obteniendo página 10...
# Página 10 guardada exitosamente (1000 juegos)
# Obteniendo página 11...
# Página 11 guardada exitosamente (1000 juegos)
# Obteniendo página 11...
# Página 11 guardada exitosamente (1000 juegos)
# Obteniendo página 12...
# Página 12 guardada exitosamente (1000 juegos)
# Obteniendo página 12...
# Página 12 guardada exitosamente (1000 juegos)
# Obteniendo página 13...
# Página 13 guardada exitosamente (1000 juegos)
# Obteniendo página 13...
# Página 13 guardada exitosamente (1000 juegos)
# Obteniendo página 14...
# Página 14 guardada exitosamente (1000 juegos)
# Obteniendo página 14...
# Página 14 guardada exitosamente (1000 juegos)
# Obteniendo página 15...
# Página 15 guardada exitosamente (1000 juegos)
# Obteniendo página 15...
# Página 15 guardada exitosamente (1000 juegos)
# Obteniendo página 16...
# Página 16 guardada exitosamente (1000 juegos)
# Obteniendo página 16...
# Página 16 guardada exitosamente (1000 juegos)
# Obteniendo página 17...
# Página 17 guardada exitosamente (1000 juegos)
# Obteniendo página 17...
# Página 17 guardada exitosamente (1000 juegos)
# Obteniendo página 18...
# Página 18 guardada exitosamente (1000 juegos)
# Obteniendo página 18...
# Página 18 guardada exitosamente (1000 juegos)
# Obteniendo página 19...
# Página 19 guardada exitosamente (1000 juegos)
# Obteniendo página 19...
# Página 19 guardada exitosamente (1000 juegos)
# Obteniendo página 20...
# Página 20 guardada exitosamente (1000 juegos)
# Obteniendo página 20...
# Página 20 guardada exitosamente (1000 juegos)
# Obteniendo página 21...
# Página 21 guardada exitosamente (1000 juegos)
# Obteniendo página 21...
# Página 21 guardada exitosamente (1000 juegos)
# Obteniendo página 22...
# Página 22 guardada exitosamente (1000 juegos)
# Obteniendo página 22...
# Página 22 guardada exitosamente (1000 juegos)
# Obteniendo página 23...
# Página 23 guardada exitosamente (1000 juegos)
# Obteniendo página 23...
# Página 23 guardada exitosamente (1000 juegos)
# Obteniendo página 24...
# Página 24 guardada exitosamente (1000 juegos)
# Obteniendo página 24...
# Página 24 guardada exitosamente (1000 juegos)
# Obteniendo página 25...
# Página 25 guardada exitosamente (1000 juegos)
# Obteniendo página 25...
# Página 25 guardada exitosamente (1000 juegos)
# Obteniendo página 26...
# Página 26 guardada exitosamente (1000 juegos)
# Obteniendo página 26...
# Página 26 guardada exitosamente (1000 juegos)
# Obteniendo página 27...
# Página 27 guardada exitosamente (1000 juegos)
# Obteniendo página 27...
# Página 27 guardada exitosamente (1000 juegos)
# Obteniendo página 28...
# Página 28 guardada exitosamente (1000 juegos)
# Obteniendo página 28...
# Página 28 guardada exitosamente (1000 juegos)
# Obteniendo página 29...
# Página 29 guardada exitosamente (1000 juegos)
# Obteniendo página 29...
# Página 29 guardada exitosamente (1000 juegos)
# Obteniendo página 30...
# Página 30 guardada exitosamente (1000 juegos)
# Obteniendo página 30...
# Página 30 guardada exitosamente (1000 juegos)
# Obteniendo página 31...
# Página 31 guardada exitosamente (1000 juegos)
# Obteniendo página 31...
# Página 31 guardada exitosamente (1000 juegos)
# Obteniendo página 32...
# Página 32 guardada exitosamente (1000 juegos)
# Obteniendo página 32...
# Página 32 guardada exitosamente (1000 juegos)
# Obteniendo página 33...
# Página 33 guardada exitosamente (1000 juegos)
# Obteniendo página 33...
# Página 33 guardada exitosamente (1000 juegos)
# Obteniendo página 34...
# Página 34 guardada exitosamente (1000 juegos)
# Obteniendo página 34...
# Página 34 guardada exitosamente (1000 juegos)
# Obteniendo página 35...
# Página 35 guardada exitosamente (1000 juegos)
# Obteniendo página 35...
# Página 35 guardada exitosamente (1000 juegos)
# Obteniendo página 36...
# Página 36 guardada exitosamente (1000 juegos)
# Obteniendo página 36...
# Página 36 guardada exitosamente (1000 juegos)
# Obteniendo página 37...
# Página 37 guardada exitosamente (1000 juegos)
# Obteniendo página 37...
# Página 37 guardada exitosamente (1000 juegos)
# Obteniendo página 38...
# Página 38 guardada exitosamente (1000 juegos)
# Obteniendo página 38...
# Página 38 guardada exitosamente (1000 juegos)
# Obteniendo página 39...
# Página 39 guardada exitosamente (1000 juegos)
# Obteniendo página 39...
# Página 39 guardada exitosamente (1000 juegos)
# Obteniendo página 40...
# Página 40 guardada exitosamente (1000 juegos)
# Obteniendo página 40...
# Página 40 guardada exitosamente (1000 juegos)
# Obteniendo página 41...
# Página 41 guardada exitosamente (1000 juegos)
# Obteniendo página 41...
# Página 41 guardada exitosamente (1000 juegos)
# Obteniendo página 42...
# Página 42 guardada exitosamente (1000 juegos)
# Obteniendo página 42...
# Página 42 guardada exitosamente (1000 juegos)
# Obteniendo página 43...
# Página 43 guardada exitosamente (1000 juegos)
# Obteniendo página 43...
# Página 43 guardada exitosamente (1000 juegos)
# Obteniendo página 44...
# Página 44 guardada exitosamente (1000 juegos)
# Obteniendo página 44...
# Página 44 guardada exitosamente (1000 juegos)
# Obteniendo página 45...
# Página 45 guardada exitosamente (1000 juegos)
# Obteniendo página 45...
# Página 45 guardada exitosamente (1000 juegos)
# Obteniendo página 46...
# Página 46 guardada exitosamente (1000 juegos)
# Obteniendo página 46...
# Página 46 guardada exitosamente (1000 juegos)
# Obteniendo página 47...
# Página 47 guardada exitosamente (1000 juegos)
# Obteniendo página 47...
# Página 47 guardada exitosamente (1000 juegos)
# Obteniendo página 48...
# Página 48 guardada exitosamente (1000 juegos)
# Obteniendo página 48...
# Página 48 guardada exitosamente (1000 juegos)
# Obteniendo página 49...
# Página 49 guardada exitosamente (1000 juegos)
# Obteniendo página 49...
# Página 49 guardada exitosamente (1000 juegos)
# Obteniendo página 50...
# Página 50 guardada exitosamente (1000 juegos)
# Obteniendo página 50...
# Página 50 guardada exitosamente (1000 juegos)
# Obteniendo página 51...
# Página 51 guardada exitosamente (1000 juegos)
# Obteniendo página 51...
# Página 51 guardada exitosamente (1000 juegos)
# Obteniendo página 52...
# Página 52 guardada exitosamente (1000 juegos)
# Obteniendo página 52...
# Página 52 guardada exitosamente (1000 juegos)
# Obteniendo página 53...
# Página 53 guardada exitosamente (1000 juegos)
# Obteniendo página 53...
# Página 53 guardada exitosamente (1000 juegos)
# Obteniendo página 54...
# Página 54 guardada exitosamente (1000 juegos)
# Obteniendo página 54...
# Página 54 guardada exitosamente (1000 juegos)
# Obteniendo página 55...
# Página 55 guardada exitosamente (1000 juegos)
# Obteniendo página 55...
# Página 55 guardada exitosamente (1000 juegos)
# Obteniendo página 56...
# Página 56 guardada exitosamente (1000 juegos)
# Obteniendo página 56...
# Página 56 guardada exitosamente (1000 juegos)
# Obteniendo página 57...
# Página 57 guardada exitosamente (1000 juegos)
# Obteniendo página 57...
# Página 57 guardada exitosamente (1000 juegos)
# Obteniendo página 58...
# Página 58 guardada exitosamente (1000 juegos)
# Obteniendo página 58...
# Página 58 guardada exitosamente (1000 juegos)
# Obteniendo página 59...
# Página 59 guardada exitosamente (1000 juegos)
# Obteniendo página 59...
# Página 59 guardada exitosamente (1000 juegos)
# Obteniendo página 60...
# Página 60 guardada exitosamente (1000 juegos)
# Obteniendo página 60...
# Página 60 guardada exitosamente (1000 juegos)
# Obteniendo página 61...
# Página 61 guardada exitosamente (1000 juegos)
# Obteniendo página 61...
# Página 61 guardada exitosamente (1000 juegos)
# Obteniendo página 62...
# Página 62 guardada exitosamente (1000 juegos)
# Obteniendo página 62...
# Página 62 guardada exitosamente (1000 juegos)
# Obteniendo página 63...
# Página 63 guardada exitosamente (1000 juegos)
# Obteniendo página 63...
# Página 63 guardada exitosamente (1000 juegos)
# Obteniendo página 64...
# Página 64 guardada exitosamente (1000 juegos)
# Obteniendo página 64...
# Página 64 guardada exitosamente (1000 juegos)
# Obteniendo página 65...
# Página 65 guardada exitosamente (1000 juegos)
# Obteniendo página 65...
# Página 65 guardada exitosamente (1000 juegos)
# Obteniendo página 66...
# Página 66 guardada exitosamente (1000 juegos)
# Obteniendo página 66...
# Página 66 guardada exitosamente (1000 juegos)
# Obteniendo página 67...
# Página 67 guardada exitosamente (1000 juegos)
# Obteniendo página 67...
# Página 67 guardada exitosamente (1000 juegos)
# Obteniendo página 68...
# Página 68 guardada exitosamente (1000 juegos)
# Obteniendo página 68...
# Página 68 guardada exitosamente (1000 juegos)
# Obteniendo página 69...
# Página 69 guardada exitosamente (1000 juegos)
# Obteniendo página 69...
# Página 69 guardada exitosamente (1000 juegos)
# Obteniendo página 70...
# Página 70 guardada exitosamente (1000 juegos)
# Obteniendo página 70...
# Página 70 guardada exitosamente (1000 juegos)
# Obteniendo página 71...
# Página 71 guardada exitosamente (1000 juegos)
# Obteniendo página 71...
# Página 71 guardada exitosamente (1000 juegos)
# Obteniendo página 72...
# Página 72 guardada exitosamente (1000 juegos)
# Obteniendo página 72...
# Página 72 guardada exitosamente (1000 juegos)
# Obteniendo página 73...
# Página 73 guardada exitosamente (1000 juegos)
# Obteniendo página 73...
# Página 73 guardada exitosamente (1000 juegos)
# Obteniendo página 74...
# Página 74 guardada exitosamente (1000 juegos)
# Obteniendo página 74...
# Página 74 guardada exitosamente (1000 juegos)
# Obteniendo página 75...
# Página 75 guardada exitosamente (1000 juegos)
# Obteniendo página 75...
# Página 75 guardada exitosamente (1000 juegos)
# Obteniendo página 76...
# Página 76 guardada exitosamente (1000 juegos)
# Obteniendo página 76...
# Página 76 guardada exitosamente (1000 juegos)
# Obteniendo página 77...
# Página 77 guardada exitosamente (1000 juegos)
# Obteniendo página 77...
# Página 77 guardada exitosamente (1000 juegos)
# Obteniendo página 78...
# Página 78 guardada exitosamente (1000 juegos)
# Obteniendo página 78...
# Página 78 guardada exitosamente (1000 juegos)
# Obteniendo página 79...
# Página 79 guardada exitosamente (1000 juegos)
# Obteniendo página 79...
# Página 79 guardada exitosamente (1000 juegos)
# Obteniendo página 80...
# Página 80 guardada exitosamente (1000 juegos)
# Obteniendo página 80...
# Página 80 guardada exitosamente (1000 juegos)
# Obteniendo página 81...
# Página 81 guardada exitosamente (1000 juegos)
# Obteniendo página 81...
# Página 81 guardada exitosamente (1000 juegos)
# Obteniendo página 82...
# Página 82 guardada exitosamente (1000 juegos)
# Obteniendo página 82...
# Página 82 guardada exitosamente (1000 juegos)
# Obteniendo página 83...
# Página 83 guardada exitosamente (1000 juegos)
# Obteniendo página 83...
# Página 83 guardada exitosamente (1000 juegos)
# Obteniendo página 84...
# Página 84 guardada exitosamente (1000 juegos)
# Obteniendo página 84...
# Página 84 guardada exitosamente (1000 juegos)
# Obteniendo página 85...
# Página 85 guardada exitosamente (1000 juegos)
# Obteniendo página 85...
# Página 85 guardada exitosamente (1000 juegos)
# Obteniendo página 86...
# Página 86 guardada exitosamente (541 juegos)
# Obteniendo página 86...
# Página 86 guardada exitosamente (541 juegos)
# Obteniendo página 87...
# Obteniendo página 87...
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\Metal\anaconda3\Lib\site-packages\requests\models.py:974, in Response.json(self, **kwargs)
#     973 try:
# --> 974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File c:\Users\Metal\anaconda3\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File c:\Users\Metal\anaconda3\Lib\json\decoder.py:345, in JSONDecoder.decode(self, s, _w)
#     341 """Return the Python representation of ``s`` (a ``str`` instance
#     342 containing a JSON document).
#     343
#     344 """
# --> 345 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     346 end = _w(s, end).end()
#
# File c:\Users\Metal\anaconda3\Lib\json\decoder.py:363, in JSONDecoder.raw_decode(self, s, idx)
#     362 except StopIteration as err:
# --> 363     raise JSONDecodeError("Expecting value", s, err.value) from None
#     364 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[3], line 65
#      62     conn.close()
#      63     print(f"Recolección de datos completada. Total de páginas: {page}")
# ---> 65 fetch_and_save_data()
#
# Cell In[3], line 27, in fetch_and_save_data()
#      24     print(f"Error: Código de estado {response.status_code}")
#      25     break
# ---> 27 data = response.json()
#      28 if not data or len(data) == 0:
#      29     print("No hay más datos disponibles")
#
# File c:\Users\Metal\anaconda3\Lib\site-packages\requests\models.py:978, in Response.json(self, **kwargs)
#     974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 978     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
