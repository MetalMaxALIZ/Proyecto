# %%
from steam_profile_games import obtener_juegos_steam
import pandas as pd
from sklearn.neighbors import NearestNeighbors
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV
import seaborn as sns
from sklearn import metrics

# %%
API_KEY = '5EF8885FBA34D73C53DD4AF7564C44C7'

# URL del perfil de Steam
perfil_url = 'https://steamcommunity.com/id/MetalMaxALIZ/'

# Obtener el DataFrame con todos los juegos
df_juegos_propios = obtener_juegos_steam(perfil_url, API_KEY)

# Mostrar información
print(f"Total de juegos: {len(df_juegos_propios)}")
df_juegos_propios.head(10)
# Out:
# Total de juegos: 473
#    app_id                                         nombre  \
# 0      10                                 Counter-Strike
# 1      30                                  Day of Defeat
# 2      40                             Deathmatch Classic
# 3      60                                       Ricochet
# 4      80                 Counter-Strike: Condition Zero
# 5     100  Counter-Strike: Condition Zero Deleted Scenes
# 6     550                                  Left 4 Dead 2
# 7     570                                         Dota 2
# 8     620                                       Portal 2
# 9     730                               Counter-Strike 2
#
#    tiempo_juego_minutos                              img_icon_url  \
# 0                  7707  6b0312cda02f5f777efa2f3318c307ff9acafbb5
# 1                     5  aadc0ce51ff6ba2042d633f8ec033b0de62091d0
# 2                    20  c525f76c8bc7353db4fd74b128c4ae2028426c2a
# 3                     6  98c69e04cd59b838e05cb6980c12c05874c6419e
# 4                   102  077b050ef3e89cd84e2c5a575d78d53b54058236
# 5                     0  077b050ef3e89cd84e2c5a575d78d53b54058236
# 6                   507  7d5a243f9500d2f8467312822f8af2a2928777ed
# 7                  2553  0bbb630d63262dd66d2fdd0f7d37e8661a410075
# 8                   376  25a5a16b2423bf7487ac5340b5b0948cef48c5f8
# 9                 37285  8dbc71957312bbd3baea65848b545be9eae2a355
#
#    tiempo_windows_minutos  tiempo_mac_minutos  tiempo_linux_minutos  \
# 0                       0                   0                     0
# 1                       0                   0                     0
# 2                       0                   0                     0
# 3                       0                   0                     0
# 4                       0                   0                     0
# 5                       0                   0                     0
# 6                       0                   0                     0
# 7                      37                   0                     0
# 8                       0                   0                     0
# 9                    9663                   0                     0
#
#    playtime_deck_forever  rtime_last_played content_descriptorids  \
# 0                      0         1475882850                [2, 5]
# 1                      0              86400                [2, 5]
# 2                      0              86400                   NaN
# 3                      0              86400                   NaN
# 4                      0              86400                [2, 5]
# 5                      0                  0                   NaN
# 6                      0         1422303949                [2, 5]
# 7                      0         1664845515                   [5]
# 8                      0         1498957512                   NaN
# 9                      0         1704987692                [2, 5]
#
#    playtime_disconnected has_community_visible_stats has_leaderboards  \
# 0                      0                         NaN              NaN
# 1                      0                         NaN              NaN
# 2                      0                         NaN              NaN
# 3                      0                         NaN              NaN
# 4                      0                         NaN              NaN
# 5                      0                         NaN              NaN
# 6                      0                        True              NaN
# 7                      0                         NaN              NaN
# 8                      0                        True             True
# 9                      0                        True              NaN
#
#    tiempo_2semanas_minutos  tiempo_juego_horas  \
# 0                      NaN          128.450000
# 1                      NaN            0.083333
# 2                      NaN            0.333333
# 3                      NaN            0.100000
# 4                      NaN            1.700000
# 5                      NaN            0.000000
# 6                      NaN            8.450000
# 7                      NaN           42.550000
# 8                      NaN            6.266667
# 9                      NaN          621.416667
#
#                                           imagen_url  \
# 0  https://cdn.cloudflare.steamstatic.com/steam/a...
# 1  https://cdn.cloudflare.steamstatic.com/steam/a...
# 2  https://cdn.cloudflare.steamstatic.com/steam/a...
# 3  https://cdn.cloudflare.steamstatic.com/steam/a...
# 4  https://cdn.cloudflare.steamstatic.com/steam/a...
# 5  https://cdn.cloudflare.steamstatic.com/steam/a...
# 6  https://cdn.cloudflare.steamstatic.com/steam/a...
# 7  https://cdn.cloudflare.steamstatic.com/steam/a...
# 8  https://cdn.cloudflare.steamstatic.com/steam/a...
# 9  https://cdn.cloudflare.steamstatic.com/steam/a...
#
#                                 store_url
# 0   https://store.steampowered.com/app/10
# 1   https://store.steampowered.com/app/30
# 2   https://store.steampowered.com/app/40
# 3   https://store.steampowered.com/app/60
# 4   https://store.steampowered.com/app/80
# 5  https://store.steampowered.com/app/100
# 6  https://store.steampowered.com/app/550
# 7  https://store.steampowered.com/app/570
# 8  https://store.steampowered.com/app/620
# 9  https://store.steampowered.com/app/730

# %%
# Nos quedamos solo con las columnas de interés 
columnas_interes = ['app_id', 'nombre', 'tiempo_juego_horas', 'imagen_url', 'store_url']
df_juegos_propios_filtrado = df_juegos_propios[columnas_interes]
df_juegos_propios_filtrado.shape
# Out:
# (473, 5)

# %%
df_juegos_propios_filtrado.head(10)
# Out:
#    app_id                                         nombre  tiempo_juego_horas  \
# 0      10                                 Counter-Strike          128.450000
# 1      30                                  Day of Defeat            0.083333
# 2      40                             Deathmatch Classic            0.333333
# 3      60                                       Ricochet            0.100000
# 4      80                 Counter-Strike: Condition Zero            1.700000
# 5     100  Counter-Strike: Condition Zero Deleted Scenes            0.000000
# 6     550                                  Left 4 Dead 2            8.450000
# 7     570                                         Dota 2           42.550000
# 8     620                                       Portal 2            6.266667
# 9     730                               Counter-Strike 2          621.416667
#
#                                           imagen_url  \
# 0  https://cdn.cloudflare.steamstatic.com/steam/a...
# 1  https://cdn.cloudflare.steamstatic.com/steam/a...
# 2  https://cdn.cloudflare.steamstatic.com/steam/a...
# 3  https://cdn.cloudflare.steamstatic.com/steam/a...
# 4  https://cdn.cloudflare.steamstatic.com/steam/a...
# 5  https://cdn.cloudflare.steamstatic.com/steam/a...
# 6  https://cdn.cloudflare.steamstatic.com/steam/a...
# 7  https://cdn.cloudflare.steamstatic.com/steam/a...
# 8  https://cdn.cloudflare.steamstatic.com/steam/a...
# 9  https://cdn.cloudflare.steamstatic.com/steam/a...
#
#                                 store_url
# 0   https://store.steampowered.com/app/10
# 1   https://store.steampowered.com/app/30
# 2   https://store.steampowered.com/app/40
# 3   https://store.steampowered.com/app/60
# 4   https://store.steampowered.com/app/80
# 5  https://store.steampowered.com/app/100
# 6  https://store.steampowered.com/app/550
# 7  https://store.steampowered.com/app/570
# 8  https://store.steampowered.com/app/620
# 9  https://store.steampowered.com/app/730

# %%
# Eliminamos los que tengan el mismo nombre
df_juegos_propios_filtrado = df_juegos_propios_filtrado.drop_duplicates(subset=['nombre'])

# %%
# Convertimos df_juegos_propios_filtrado a un diccionario para facilitar la búsqueda
juegos_dict = df_juegos_propios_filtrado.set_index('nombre').T.to_dict('index')
juegos_dict
# Out:
# {'app_id': {'Counter-Strike': 10,
#   'Day of Defeat': 30,
#   'Deathmatch Classic': 40,
#   'Ricochet': 60,
#   'Counter-Strike: Condition Zero': 80,
#   'Counter-Strike: Condition Zero Deleted Scenes': 100,
#   'Left 4 Dead 2': 550,
#   'Dota 2': 570,
#   'Portal 2': 620,
#   'Counter-Strike 2': 730,
#   'Psychonauts': 3830,
#   "Sid Meier's Civilization IV": 3900,
#   "Sid Meier's Civilization III: Complete": 3910,
#   "Sid Meier's Pirates!": 3920,
#   "Sid Meier's Civilization IV: Warlords": 3990,
#   "Garry's Mod": 4000,
#   'Condemned: Criminal Origins': 4720,
#   'Natural Selection 2': 4920,
#   'Hitman 2: Silent Assassin': 6850,
#   'Hitman: Codename 47': 6900,
#   'X-Blades': 7510,
#   'Two Worlds II HD': 7520,
#   'Two Worlds II Castle Defense': 7530,
#   "Sid Meier's Railroads!": 7600,
#   'BioShock': 7670,
#   'Kane & Lynch: Dead Men': 8080,
#   'Just Cause 2': 8190,
#   "Sid Meier's Civilization IV: Beyond the Sword": 8800,
#   "Sid Meier's Civilization V": 8930,
#   'Saints Row 2': 9480,
#   'Overlord': 11450,
#   'Overlord: Raising Hell': 12710,
#   'Rise of the Argonauts': 12770,
#   'Operation Flashpoint: Dragon Rising': 12830,
#   'AaaaaAAaaaAAAaaAAAAaAAAAA!!! for the Awesome': 15560,
#   "Oddworld: Abe's Oddysee": 15700,
#   'F.E.A.R. 2: Project Origin': 16450,
#   "Sid Meier's Civilization IV: Colonization": 16810,
#   "Mirror's Edge": 17410,
#   'Dead Space (2008)': 17470,
#   'Nuclear Dawn': 17710,
#   'Crazy Machines 2': 18400,
#   'Alice: Madness Returns': 19680,
#   'F.E.A.R.': 21090,
#   'F.E.A.R. 3': 21100,
#   'F.E.A.R.: Extraction Point': 21110,
#   'F.E.A.R.: Perseus Mandate': 21120,
#   'Bionic Commando Rearmed': 21680,
#   'Resident Evil 5': 21690,
#   'Rock of Ages': 22230,
#   'Burnout Paradise: The Ultimate Box': 24740,
#   'Command & Conquer™ Red Alert™ 3 - Uprising': 24800,
#   'Kane & Lynch 2: Dog Days': 28000,
#   'Osmos': 29180,
#   'The Lord of the Rings: War in the North': 32800,
#   'Broken Sword 2 - the Smoking Mirror: Remastered (2010)': 33600,
#   'SEGA Mega Drive & Genesis Classics': 34270,
#   'Mini Ninjas': 35000,
#   'Batman: Arkham Asylum GOTY Edition': 35140,
#   'Rising Storm/Red Orchestra 2 Multiplayer': 35450,
#   'Trine 2': 35720,
#   'RIFT': 39120,
#   'The Guild II': 39650,
#   'The Guild II - Pirates of the European Seas': 39660,
#   'The Guild II: Renaissance': 39680,
#   'Supreme Commander 2': 40100,
#   'Risen': 40300,
#   'Risen 2 - Dark Waters': 40390,
#   'Serious Sam 3: BFE': 41070,
#   'Magicka': 42910,
#   'Metro 2033': 43110,
#   'Metro: Last Light Complete Edition': 43160,
#   'Galcon Fusion': 44200,
#   'Operation Flashpoint: Red River': 44340,
#   'Medal of Honor(TM) Single Player': 47790,
#   'Medal of Honor(TM) Multiplayer': 47830,
#   'Saints Row: The Third': 55230,
#   'Amnesia: The Dark Descent': 57300,
#   'Zen Bound® 2': 61600,
#   'Sniper Elite V2': 63380,
#   'Dustforce': 65300,
#   'Arma: Cold War Assault': 65790,
#   'Dungeon Defenders': 65800,
#   'The Bureau: XCOM Declassified': 65930,
#   'The Darkness II': 67370,
#   'Dino D-Day': 70000,
#   'VVVVVV': 70300,
#   'Worms Ultimate Mayhem': 70600,
#   'Worms Crazy Golf': 70620,
#   'Worms Blast': 70650,
#   'Worms Pinball': 70660,
#   'Star Ruler': 70900,
#   'The Elder Scrolls V: Skyrim': 72850,
#   'Puzzle Bots': 80300,
#   'Dead Island': 91310,
#   'Sanctum': 91600,
#   'Nidhogg': 94400,
#   'Capsized': 95300,
#   'Ravaged Zombie Apocalypse': 96300,
#   'Dungeons of Dredmor': 98800,
#   'Orcs Must Die!': 102600,
#   'Shank 2': 102840,
#   'ORION: Prelude': 104900,
#   'Terraria': 105600,
#   'Project Zomboid': 108600,
#   'Crysis 2 Maximum Edition': 108800,
#   'Blocks That Matter': 111800,
#   'Guardians of Middle-earth': 111900,
#   'Costume Quest': 115100,
#   'Stacking': 115110,
#   'Nosgoth': 200110,
#   'Realm of the Mad God Exalt': 200210,
#   'Batman: Arkham City GOTY': 200260,
#   'Torchlight II': 200710,
#   'Cave Story+': 200900,
#   'Galcon Legends': 201040,
#   'Really Big Sky': 201570,
#   'Orcs Must Die! 2': 201790,
#   'Galactic Civilizations II: Ultimate Edition': 202200,
#   'Hitman: Absolution': 203140,
#   'Titan Attacks': 203210,
#   'Binary Domain': 203750,
#   'Dear Esther': 203810,
#   'Awesomenauts': 204300,
#   'Call of Juarez Gunslinger': 204450,
#   'Retro City Rampage™ DX': 204630,
#   'Lumino City': 205020,
#   'Dishonored': 205100,
#   'Hell Yeah!': 205230,
#   'Mortal Kombat Kollection': 205350,
#   'Insanely Twisted Shadow Planet': 205730,
#   "Tiny and Big: Grandpa's Leftovers": 205910,
#   'Jet Set Radio': 205950,
#   'Gunpoint': 206190,
#   'To the Moon': 206440,
#   '3SwitcheD': 206610,
#   'SpeedRunners': 207140,
#   'Hack, Slash, Loot': 207430,
#   'Symphony': 207750,
#   'Blades of Time': 208670,
#   'Batman™: Arkham Origins': 209000,
#   'Spirits': 210170,
#   'Sanctum 2': 210770,
#   'Battle vs Chess': 211050,
#   'Deadlight': 211400,
#   'DARK SOULS™: Prepare To Die Edition': 211420,
#   'Wanderlust: Rebirth': 211580,
#   'Thief Gold': 211600,
#   'Galaxy on Fire 2™ Full HD': 212010,
#   'TERA': 212740,
#   'Guacamelee! Gold Edition': 214770,
#   'The Incredible Adventures of Van Helsing': 215530,
#   'Dream Pinball 3D': 215790,
#   'Jagged Alliance 2 - Wildfire ': 215930,
#   'BIT.TRIP Presents... Runner2: Future Legend of Rhythm Alien': 218060,
#   'PAYDAY 2': 218620,
#   'Scribblenauts Unlimited': 218680,
#   'Chivalry: Medieval Warfare': 219640,
#   "Don't Starve": 219740,
#   'Antichamber': 219890,
#   'DmC Devil May Cry': 220440,
#   'RPG Maker VX Ace': 220700,
#   'Thomas Was Alone': 220780,
#   'Little Inferno': 221260,
#   'Super Hexagon': 221640,
#   'Resident Evil Revelations': 222480,
#   'Reus': 222730,
#   'Giana Sisters: Twisted Dreams': 223220,
#   'Cry of Fear': 223710,
#   'Pressure': 224220,
#   'Iron Sky Invasion': 224900,
#   'Duke Nukem 3D: Megaton Edition': 225140,
#   'Shadow Warrior Classic Redux': 225160,
#   'Cities in Motion 2': 225420,
#   'Sacred 2 Gold': 225640,
#   'Lost Planet 3': 226720,
#   'Papo & Yo': 227080,
#   'Heroes & Generals': 227940,
#   'Remember Me': 228300,
#   'Warframe': 230410,
#   'Beatbuddy: Tale of the Guardians': 231040,
#   'The Swapper': 231160,
#   'Knights of Pen and Paper +1': 231740,
#   'Killing Floor 2': 232090,
#   'Broken Age': 232790,
#   'Shadow Warrior': 233130,
#   'MURDERED: SOUL SUSPECT™': 233290,
#   'Avadon 2: The Corruption': 233310,
#   'Superfrog HD': 234000,
#   "Ken Follett's The Pillars of the Earth": 234270,
#   'Teleglitch: Die More Edition': 234390,
#   'Strider': 235210,
#   'Tetrobot and Co.': 235980,
#   'Dust: An Elysian Tail': 236090,
#   'Dungeon Defenders II': 236110,
#   'DARK SOULS™ II': 236430,
#   'Red Orchestra 2: Heroes of Stalingrad - Single Player': 236830,
#   "Deus Ex: Human Revolution - Director's Cut": 238010,
#   'Outlast': 238320,
#   'Path of Exile': 238960,
#   'Hammerwatch': 239070,
#   'Thief': 239160,
#   'The Mighty Quest For Epic Loot': 239220,
#   'Guncraft': 241720,
#   "Assassin's Creed IV Black Flag": 242050,
#   'Joe Danger 2: The Movie': 242110,
#   'The Chaos Engine': 242530,
#   'Injustice: Gods Among Us Ultimate Edition': 242700,
#   'Anachronox': 242940,
#   'Daikatana': 242980,
#   "Sid Meier's Ace Patrol": 244070,
#   "Sid Meier's Ace Patrol: Pacific Skies": 244090,
#   'Happy Wars': 246280,
#   'Kingdom Rush': 246420,
#   'Talisman: Digital Classic Edition': 247000,
#   'Cook, Serve, Delicious!': 247020,
#   'Volgarr the Viking': 247240,
#   'Sacred 3': 247950,
#   'Clickteam Fusion 2.5': 248170,
#   'Draw a Stickman: EPIC': 248650,
#   'The Wolf Among Us': 250320,
#   'How to Survive': 250400,
#   'Bridge Constructor': 250460,
#   'Paranautical Activity: Deluxe Atonement Edition': 250580,
#   'The Binding of Isaac: Rebirth': 250900,
#   'The Inner World': 251430,
#   'Speedball 2 HD': 251690,
#   'Legend of Grimrock 2': 251730,
#   'Oniken': 252010,
#   'Divide by Sheep': 252130,
#   'Syder Arcade': 252310,
#   'The Shivah': 252370,
#   'SteamWorld Dig': 252410,
#   'Nihilumbra': 252670,
#   'Ravensword: Shadowlands': 253410,
#   'Earth 2140 HD': 253860,
#   'Gorky 17': 253920,
#   'Septerra Core': 253940,
#   "Jack Orlando Director's Cut": 253960,
#   'Enclave': 253980,
#   'Commander: Conquest of the Americas Gold': 254020,
#   'World War III: Black Gold': 254080,
#   'Resident Evil 4 (2005)': 254700,
#   'Viscera Cleanup Detail: Shadow Warrior': 255520,
#   'Cities: Skylines': 255710,
#   'Blast Em!': 257630,
#   'Bloody Trapland': 257750,
#   'Talisman: Prologue': 258200,
#   'Type:Rider': 258890,
#   "Montague's Mount": 258950,
#   'Heli Heroes': 259320,
#   'Chicken Shoot Gold': 259340,
#   'Chicken Shoot 2': 259360,
#   'Savant - Ascent': 259530,
#   '1001 Spikes': 260790,
#   'Lethal League': 261180,
#   'Dungeons 2': 262280,
#   'Alpha Kimori™ Episode One ': 265870,
#   'Tower of Guns': 266110,
#   'AR-K': 269890,
#   'Robot Roller-Derby Disco Dodgeball': 270450,
#   'Card City Nights': 271820,
#   'Vertiginous Golf': 272890,
#   'Counter-Strike Nexon': 273110,
#   'Evolve Stage 2': 273350,
#   'OlliOlli': 274250,
#   'Skara - The Blade Remains': 274620,
#   'Guacamelee! Super Turbo Championship Edition': 275390,
#   'Skyborn': 278460,
#   'Richard & Alice': 279260,
#   'The I of the Dragon': 279720,
#   "A Wizard's Lizard": 280040,
#   'LEGO® The Hobbit™': 285160,
#   'RollerCoaster Tycoon 2: Triple Thrill Pack': 285330,
#   'Tabletop Simulator': 286160,
#   'Metro 2033 Redux': 286690,
#   'Resident Evil Revelations 2': 287290,
#   'Metro: Last Light Redux': 287390,
#   'Brawlhalla': 291550,
#   'The Lost Crown': 291710,
#   'Never Alone (Kisima Ingitchuna)': 295790,
#   'The Great Jitters: Pudding Panic': 296650,
#   'Titan Souls': 297130,
#   'Spy Chameleon - RGB Agent': 297490,
#   'Only If': 298260,
#   'Sweet Lily Dreams': 300540,
#   'GALAK-Z': 300580,
#   "The Beginner's Guide": 303210,
#   'Trove': 304050,
#   'Unturned': 304930,
#   'Mortal Kombat X': 307780,
#   'Savage Lands': 307880,
#   'The Nightmare Cooperative': 310070,
#   'Call of Duty: Black Ops III': 311210,
#   'Vertical Drop Heroes HD': 311480,
#   'Enter the Gungeon': 311690,
#   'Rain World': 312520,
#   'Pool Nation FX': 314000,
#   'Hazard Ops': 319150,
#   'Absolute Drift': 320140,
#   "Don't Starve Together": 322330,
#   'Tharsis': 323060,
#   'Grow Home': 323320,
#   'Jotun: Valhalla Edition': 323580,
#   'TOXIKK': 324810,
#   'May’s Mysteries: The Secret of Dragonville': 327650,
#   'Spriter Pro': 332360,
#   'Epic Arena': 334030,
#   'Runestone Keeper': 339400,
#   'Particula': 343360,
#   'KHOLAT': 343710,
#   'Victor Vran': 345180,
#   'ARK: Survival Evolved': 346110,
#   'NARUTO SHIPPUDEN: Ultimate Ninja STORM 4': 349040,
#   'Valhalla Hills': 351910,
#   'Styx: Shards of Darkness': 355790,
#   'Snakebird': 357300,
#   'Evoland 2': 359310,
#   "Tom Clancy's Rainbow Six® Siege X": 359550,
#   'Uncanny Valley': 359580,
#   'Choice Chamber': 359960,
#   'Remnants of Isolation': 360010,
#   'Yooka-Laylee': 360830,
#   'Volume': 365770,
#   'No Time To Explain Remastered': 368730,
#   'Ghost in the Shell: Stand Alone Complex - First Assault Online': 369200,
#   'TIS-100': 370360,
#   'DARK SOULS™ III': 374320,
#   'Pale Echoes': 377190,
#   'Fishing Planet': 380600,
#   'Dead by Daylight': 381210,
#   'Sakura Clicker': 383080,
#   'INK': 385710,
#   'SMITE': 386360,
#   'Cook, Serve, Delicious! 2!!': 386620,
#   'Mitos.is: The Game': 389570,
#   'TEKKEN 7': 389730,
#   'Acceleration of SUGURI 2': 390710,
#   'Undertale': 391540,
#   'Necromonads': 391630,
#   'Dark Heritage: Guardians of Hope': 394280,
#   'The Secret Order 2: Masked Intent': 399890,
#   'Else Heart.Break()': 400110,
#   'Tabletopia': 402560,
#   'ARK: Survival Of The Fittest': 407530,
#   'BioShock Remastered': 409710,
#   'Stardew Valley': 413150,
#   'Vampire Legends: The True Story of Kisilova': 414660,
#   'Tick Tock Isle': 418440,
#   'Plantera': 421040,
#   'Devil Daggers': 422970,
#   'Road to Ballhalla': 425410,
#   'Wallpaper Engine': 431960,
#   'Divinity: Original Sin 2': 435150,
#   'Shadowverse': 453480,
#   'Deceit': 466240,
#   'Minion Masters': 489520,
#   'The Elder Scrolls V: Skyrim Special Edition': 489830,
#   'Battlerite': 504370,
#   'Last Man Standing': 506540,
#   'SCUM': 513710,
#   'Dear Esther: Landmark Edition': 520720,
#   'Darwin Project': 544920,
#   'Warhammer: Vermintide 2': 552500,
#   'Serious Sam Fusion 2017 (beta)': 564310,
#   'Golf It!': 571740,
#   'PUBG: BATTLEGROUNDS': 578080,
#   'Monster Hunter: World': 582010,
#   'We Were Here': 582500,
#   'Black Desert': 582660,
#   "Tom Clancy's Ghost Recon Wildlands Open Beta": 584210,
#   'Fallout Shelter': 588430,
#   'Ni no Kuni™ II: Revenant Kingdom': 589360,
#   'Hunt: Showdown 1896': 594650,
#   'SOS': 619080,
#   "Tom Clancy's Rainbow Six Siege - Test Server": 623990,
#   'Slay the Spire': 646570,
#   'BattleBit Remastered': 671860,
#   'SCP: Secret Laboratory': 700330,
#   'Cube Racer': 705210,
#   'Warhammer: Vermintide 2 Closed Test': 737010,
#   'Phasmophobia': 739630,
#   'Temtem': 745920,
#   'Hunt: Showdown 1896 (Test Server)': 770720,
#   "Bear With Me - Collector's Edition": 783050,
#   'Outward': 794260,
#   'METAL GEAR SURVIVE BETA': 797470,
#   'SOS: Classic': 802240,
#   'Radical Heights': 809960,
#   'Realm Royale Reforged': 813820,
#   'Totally Accurate Battlegrounds': 823130,
#   'Noita': 881100,
#   'CRSED: Cuisine Royale': 884660,
#   'Among Us': 945360,
#   'Gothic Playable Teaser': 950670,
#   'Bloons TD 6': 960090,
#   'Element TD 2': 1018830,
#   'Evoland Legendary Edition': 1020470,
#   'New World: Aeternum': 1063730,
#   'Destiny 2': 1085660,
#   "Baldur's Gate 3": 1086940,
#   'Fall Guys': 1097150,
#   'RISK: Global Domination': 1128810,
#   'Apex Legends': 1172470,
#   'FINAL FANTASY': 1173770,
#   'FINAL FANTASY II': 1173780,
#   'FINAL FANTASY III': 1173790,
#   'FINAL FANTASY IV': 1173800,
#   'FINAL FANTASY V': 1173810,
#   'FINAL FANTASY VI': 1173820,
#   'Mind Over Magic': 1270580,
#   'tModLoader': 1281930,
#   'Loop Hero': 1282730,
#   'SUPERVIVE': 1283700,
#   'Deadlock': 1422450,
#   'Yu-Gi-Oh!  Master Duel': 1449850,
#   'IdleOn': 1476970,
#   'Sker Ritual': 1492070,
#   'Century Playtest': 1492330,
#   'Disney Speedstorm': 1537830,
#   'NARAKA: BLADEPOINT Playtest': 1584640,
#   'Lost Ark': 1599340,
#   'SUPER PEOPLE Testing Grounds': 1619990,
#   'Palworld': 1623730,
#   'For The King II': 1676840,
#   'New World: Aeternum Open Beta': 1724660,
#   'Crab Game': 1782210,
#   'DRAGON BALL: Sparking! ZERO': 1790600,
#   'Lost Ark Closed Technical Beta ': 1793660,
#   'Vampire Survivors': 1794680,
#   'STALCRAFT: X': 1818450,
#   'Monster Hunter Rise: Sunbreak Demo': 1836450,
#   'Call of Duty®': 1938090,
#   'Brotato': 1942280,
#   'Digimon Story Time Stranger': 1984270,
#   'MARVEL SNAP': 1997040,
#   'Soulstone Survivors': 2066020,
#   'Dark and Darker Playtest': 2078890,
#   'Unsolved Case': 2084050,
#   'Escape Memoirs: Mini Stories': 2098350,
#   'What the Fog': 2139020,
#   'Monster Hunter Wilds': 2246340,
#   'Savant - Ascent REMIX': 2279330,
#   'Mind Over Magic Playtest': 2354320,
#   'Black Myth: Wukong': 2358720,
#   'Balatro': 2379780,
#   'Horizon Forbidden West™ Complete Edition': 2420110,
#   'SMITE 2': 2437170,
#   'Dungeonborne': 2448970,
#   'Dungeonborne Playtest': 2452260,
#   "Rusty's Retirement": 2666510,
#   'Path of Exile 2': 2694490,
#   'Revolution Idle': 2763740,
#   'Content Warning': 2881650,
#   'Nuclear Nightmare': 2909110,
#   'Persona5: The Phantom X': 3061570,
#   'Monster Hunter Wilds Beta test': 3065170,
#   'Battlefield™ 6 Open Beta': 3081410,
#   'Temtem: Swarm Playtest': 3101950,
#   'Umamusume: Pretty Derby': 3224770,
#   'Deadzone Rogue': 3228590,
#   'Megabonk': 3405340,
#   'Bongo Cat': 3419430,
#   'Gods, Death & Reapers Playtest': 3475870,
#   'Cast n Chill': 3483740,
#   'PEAK': 3527290,
#   'King of Meat - Technical Test': 3560320,
#   'MISERY Playtest': 3847130,
#   'Final Sentence Demo': 4021860},
#  'tiempo_juego_horas': {'Counter-Strike': 128.45,
#   'Day of Defeat': 0.08333333333333333,
#   'Deathmatch Classic': 0.3333333333333333,
#   'Ricochet': 0.1,
#   'Counter-Strike: Condition Zero': 1.7,
#   'Counter-Strike: Condition Zero Deleted Scenes': 0.0,
#   'Left 4 Dead 2': 8.45,
#   'Dota 2': 42.55,
#   'Portal 2': 6.266666666666667,
#   'Counter-Strike 2': 621.4166666666666,
#   'Psychonauts': 0.0,
#   "Sid Meier's Civilization IV": 0.0,
#   "Sid Meier's Civilization III: Complete": 0.0,
#   "Sid Meier's Pirates!": 0.0,
#   "Sid Meier's Civilization IV: Warlords": 0.0,
#   "Garry's Mod": 60.2,
#   'Condemned: Criminal Origins': 0.0,
#   'Natural Selection 2': 4.766666666666667,
#   'Hitman 2: Silent Assassin': 0.0,
#   'Hitman: Codename 47': 0.0,
#   'X-Blades': 0.4166666666666667,
#   'Two Worlds II HD': 0.4166666666666667,
#   'Two Worlds II Castle Defense': 0.4166666666666667,
#   "Sid Meier's Railroads!": 0.0,
#   'BioShock': 0.9,
#   'Kane & Lynch: Dead Men': 0.0,
#   'Just Cause 2': 4.333333333333333,
#   "Sid Meier's Civilization IV: Beyond the Sword": 0.0,
#   "Sid Meier's Civilization V": 2.45,
#   'Saints Row 2': 0.0,
#   'Overlord': 0.016666666666666666,
#   'Overlord: Raising Hell': 0.18333333333333332,
#   'Rise of the Argonauts': 0.0,
#   'Operation Flashpoint: Dragon Rising': 0.21666666666666667,
#   'AaaaaAAaaaAAAaaAAAAaAAAAA!!! for the Awesome': 0.5333333333333333,
#   "Oddworld: Abe's Oddysee": 0.0,
#   'F.E.A.R. 2: Project Origin': 0.36666666666666664,
#   "Sid Meier's Civilization IV: Colonization": 0.0,
#   "Mirror's Edge": 0.9666666666666667,
#   'Dead Space (2008)': 8.083333333333334,
#   'Nuclear Dawn': 0.0,
#   'Crazy Machines 2': 0.0,
#   'Alice: Madness Returns': 22.6,
#   'F.E.A.R.': 0.7666666666666667,
#   'F.E.A.R. 3': 0.5666666666666667,
#   'F.E.A.R.: Extraction Point': 0.0,
#   'F.E.A.R.: Perseus Mandate': 0.0,
#   'Bionic Commando Rearmed': 0.0,
#   'Resident Evil 5': 5.5,
#   'Rock of Ages': 0.7666666666666667,
#   'Burnout Paradise: The Ultimate Box': 0.5,
#   'Command & Conquer™ Red Alert™ 3 - Uprising': 0.08333333333333333,
#   'Kane & Lynch 2: Dog Days': 0.0,
#   'Osmos': 0.16666666666666666,
#   'The Lord of the Rings: War in the North': 0.0,
#   'Broken Sword 2 - the Smoking Mirror: Remastered (2010)': 0.0,
#   'SEGA Mega Drive & Genesis Classics': 0.5666666666666667,
#   'Mini Ninjas': 0.36666666666666664,
#   'Batman: Arkham Asylum GOTY Edition': 0.0,
#   'Rising Storm/Red Orchestra 2 Multiplayer': 0.0,
#   'Trine 2': 3.966666666666667,
#   'RIFT': 3.466666666666667,
#   'The Guild II': 0.0,
#   'The Guild II - Pirates of the European Seas': 0.0,
#   'The Guild II: Renaissance': 0.0,
#   'Supreme Commander 2': 0.0,
#   'Risen': 0.0,
#   'Risen 2 - Dark Waters': 0.0,
#   'Serious Sam 3: BFE': 1.3833333333333333,
#   'Magicka': 5.233333333333333,
#   'Metro 2033': 0.0,
#   'Metro: Last Light Complete Edition': 0.0,
#   'Galcon Fusion': 0.0,
#   'Operation Flashpoint: Red River': 0.0,
#   'Medal of Honor(TM) Single Player': 0.0,
#   'Medal of Honor(TM) Multiplayer': 2.5166666666666666,
#   'Saints Row: The Third': 0.0,
#   'Amnesia: The Dark Descent': 0.0,
#   'Zen Bound® 2': 0.31666666666666665,
#   'Sniper Elite V2': 1.35,
#   'Dustforce': 0.1,
#   'Arma: Cold War Assault': 0.0,
#   'Dungeon Defenders': 12.3,
#   'The Bureau: XCOM Declassified': 0.0,
#   'The Darkness II': 5.7,
#   'Dino D-Day': 0.5166666666666667,
#   'VVVVVV': 1.1833333333333333,
#   'Worms Ultimate Mayhem': 1.6,
#   'Worms Crazy Golf': 0.0,
#   'Worms Blast': 0.0,
#   'Worms Pinball': 0.0,
#   'Star Ruler': 0.0,
#   'The Elder Scrolls V: Skyrim': 29.75,
#   'Puzzle Bots': 0.0,
#   'Dead Island': 0.0,
#   'Sanctum': 0.0,
#   'Nidhogg': 4.05,
#   'Capsized': 0.0,
#   'Ravaged Zombie Apocalypse': 0.5333333333333333,
#   'Dungeons of Dredmor': 0.48333333333333334,
#   'Orcs Must Die!': 2.3,
#   'Shank 2': 0.31666666666666665,
#   'ORION: Prelude': 1.15,
#   'Terraria': 193.41666666666666,
#   'Project Zomboid': 28.866666666666667,
#   'Crysis 2 Maximum Edition': 3.683333333333333,
#   'Blocks That Matter': 0.4666666666666667,
#   'Guardians of Middle-earth': 3.9166666666666665,
#   'Costume Quest': 10.083333333333334,
#   'Stacking': 11.133333333333333,
#   'Nosgoth': 1.0166666666666666,
#   'Realm of the Mad God Exalt': 27.383333333333333,
#   'Batman: Arkham City GOTY': 10.45,
#   'Torchlight II': 6.266666666666667,
#   'Cave Story+': 0.0,
#   'Galcon Legends': 0.23333333333333334,
#   'Really Big Sky': 0.23333333333333334,
#   'Orcs Must Die! 2': 6.2,
#   'Galactic Civilizations II: Ultimate Edition': 0.0,
#   'Hitman: Absolution': 0.0,
#   'Titan Attacks': 2.6666666666666665,
#   'Binary Domain': 0.0,
#   'Dear Esther': 0.03333333333333333,
#   'Awesomenauts': 2.716666666666667,
#   'Call of Juarez Gunslinger': 0.0,
#   'Retro City Rampage™ DX': 0.0,
#   'Lumino City': 0.0,
#   'Dishonored': 4.7,
#   'Hell Yeah!': 4.283333333333333,
#   'Mortal Kombat Kollection': 1.3666666666666667,
#   'Insanely Twisted Shadow Planet': 0.85,
#   "Tiny and Big: Grandpa's Leftovers": 0.4166666666666667,
#   'Jet Set Radio': 0.0,
#   'Gunpoint': 0.0,
#   'To the Moon': 0.4166666666666667,
#   '3SwitcheD': 0.0,
#   'SpeedRunners': 0.55,
#   'Hack, Slash, Loot': 0.48333333333333334,
#   'Symphony': 1.1833333333333333,
#   'Blades of Time': 0.9833333333333333,
#   'Batman™: Arkham Origins': 11.4,
#   'Spirits': 0.0,
#   'Sanctum 2': 7.8,
#   'Battle vs Chess': 0.16666666666666666,
#   'Deadlight': 2.3666666666666667,
#   'DARK SOULS™: Prepare To Die Edition': 4.816666666666666,
#   'Wanderlust: Rebirth': 0.4166666666666667,
#   'Thief Gold': 0.0,
#   'Galaxy on Fire 2™ Full HD': 0.0,
#   'TERA': 42.53333333333333,
#   'Guacamelee! Gold Edition': 2.15,
#   'The Incredible Adventures of Van Helsing': 2.05,
#   'Dream Pinball 3D': 0.0,
#   'Jagged Alliance 2 - Wildfire ': 0.0,
#   'BIT.TRIP Presents... Runner2: Future Legend of Rhythm Alien': 1.3666666666666667,
#   'PAYDAY 2': 0.9166666666666666,
#   'Scribblenauts Unlimited': 0.8666666666666667,
#   'Chivalry: Medieval Warfare': 31.55,
#   "Don't Starve": 24.9,
#   'Antichamber': 1.4,
#   'DmC Devil May Cry': 1.3166666666666667,
#   'RPG Maker VX Ace': 2.216666666666667,
#   'Thomas Was Alone': 0.0,
#   'Little Inferno': 3.3,
#   'Super Hexagon': 0.0,
#   'Resident Evil Revelations': 0.0,
#   'Reus': 0.9666666666666667,
#   'Giana Sisters: Twisted Dreams': 0.0,
#   'Cry of Fear': 8.583333333333334,
#   'Pressure': 0.0,
#   'Iron Sky Invasion': 0.0,
#   'Duke Nukem 3D: Megaton Edition': 0.0,
#   'Shadow Warrior Classic Redux': 0.0,
#   'Cities in Motion 2': 0.55,
#   'Sacred 2 Gold': 0.0,
#   'Lost Planet 3': 2.6166666666666667,
#   'Papo & Yo': 0.0,
#   'Heroes & Generals': 0.31666666666666665,
#   'Remember Me': 0.0,
#   'Warframe': 1.15,
#   'Beatbuddy: Tale of the Guardians': 0.0,
#   'The Swapper': 1.15,
#   'Knights of Pen and Paper +1': 0.0,
#   'Killing Floor 2': 43.0,
#   'Broken Age': 0.0,
#   'Shadow Warrior': 1.85,
#   'MURDERED: SOUL SUSPECT™': 0.48333333333333334,
#   'Avadon 2: The Corruption': 0.0,
#   'Superfrog HD': 0.25,
#   "Ken Follett's The Pillars of the Earth": 0.0,
#   'Teleglitch: Die More Edition': 0.0,
#   'Strider': 1.0833333333333333,
#   'Tetrobot and Co.': 0.0,
#   'Dust: An Elysian Tail': 4.483333333333333,
#   'Dungeon Defenders II': 35.5,
#   'DARK SOULS™ II': 53.13333333333333,
#   'Red Orchestra 2: Heroes of Stalingrad - Single Player': 0.0,
#   "Deus Ex: Human Revolution - Director's Cut": 0.0,
#   'Outlast': 0.3,
#   'Path of Exile': 563.45,
#   'Hammerwatch': 24.666666666666668,
#   'Thief': 0.4166666666666667,
#   'The Mighty Quest For Epic Loot': 9.016666666666667,
#   'Guncraft': 0.21666666666666667,
#   "Assassin's Creed IV Black Flag": 27.166666666666668,
#   'Joe Danger 2: The Movie': 0.38333333333333336,
#   'The Chaos Engine': 0.06666666666666667,
#   'Injustice: Gods Among Us Ultimate Edition': 10.55,
#   'Anachronox': 0.0,
#   'Daikatana': 0.0,
#   "Sid Meier's Ace Patrol": 0.0,
#   "Sid Meier's Ace Patrol: Pacific Skies": 0.0,
#   'Happy Wars': 0.6,
#   'Kingdom Rush': 0.9833333333333333,
#   'Talisman: Digital Classic Edition': 0.03333333333333333,
#   'Cook, Serve, Delicious!': 0.0,
#   'Volgarr the Viking': 2.533333333333333,
#   'Sacred 3': 1.6166666666666667,
#   'Clickteam Fusion 2.5': 0.0,
#   'Draw a Stickman: EPIC': 0.13333333333333333,
#   'The Wolf Among Us': 6.166666666666667,
#   'How to Survive': 11.966666666666667,
#   'Bridge Constructor': 3.033333333333333,
#   'Paranautical Activity: Deluxe Atonement Edition': 11.533333333333333,
#   'The Binding of Isaac: Rebirth': 499.95,
#   'The Inner World': 0.0,
#   'Speedball 2 HD': 0.0,
#   'Legend of Grimrock 2': 0.0,
#   'Oniken': 0.0,
#   'Divide by Sheep': 0.0,
#   'Syder Arcade': 0.48333333333333334,
#   'The Shivah': 0.4166666666666667,
#   'SteamWorld Dig': 0.0,
#   'Nihilumbra': 0.0,
#   'Ravensword: Shadowlands': 0.0,
#   'Earth 2140 HD': 0.0,
#   'Gorky 17': 0.0,
#   'Septerra Core': 0.0,
#   "Jack Orlando Director's Cut": 0.0,
#   'Enclave': 0.0,
#   'Commander: Conquest of the Americas Gold': 0.0,
#   'World War III: Black Gold': 0.4166666666666667,
#   'Resident Evil 4 (2005)': 8.466666666666667,
#   'Viscera Cleanup Detail: Shadow Warrior': 0.7166666666666667,
#   'Cities: Skylines': 2.5833333333333335,
#   'Blast Em!': 0.016666666666666666,
#   'Bloody Trapland': 2.183333333333333,
#   'Talisman: Prologue': 0.0,
#   'Type:Rider': 0.5333333333333333,
#   "Montague's Mount": 0.0,
#   'Heli Heroes': 0.0,
#   'Chicken Shoot Gold': 0.0,
#   'Chicken Shoot 2': 0.0,
#   'Savant - Ascent': 0.9166666666666666,
#   '1001 Spikes': 5.7,
#   'Lethal League': 0.0,
#   'Dungeons 2': 6.15,
#   'Alpha Kimori™ Episode One ': 0.0,
#   'Tower of Guns': 0.4166666666666667,
#   'AR-K': 0.0,
#   'Robot Roller-Derby Disco Dodgeball': 0.0,
#   'Card City Nights': 0.0,
#   'Vertiginous Golf': 0.6833333333333333,
#   'Counter-Strike Nexon': 0.8,
#   'Evolve Stage 2': 15.6,
#   'OlliOlli': 0.0,
#   'Skara - The Blade Remains': 0.0,
#   'Guacamelee! Super Turbo Championship Edition': 0.0,
#   'Skyborn': 0.0,
#   'Richard & Alice': 0.0,
#   'The I of the Dragon': 0.0,
#   "A Wizard's Lizard": 1.05,
#   'LEGO® The Hobbit™': 4.283333333333333,
#   'RollerCoaster Tycoon 2: Triple Thrill Pack': 0.0,
#   'Tabletop Simulator': 3.4,
#   'Metro 2033 Redux': 4.716666666666667,
#   'Resident Evil Revelations 2': 0.0,
#   'Metro: Last Light Redux': 0.8666666666666667,
#   'Brawlhalla': 0.7333333333333333,
#   'The Lost Crown': 0.0,
#   'Never Alone (Kisima Ingitchuna)': 0.0,
#   'The Great Jitters: Pudding Panic': 0.0,
#   'Titan Souls': 1.0333333333333334,
#   'Spy Chameleon - RGB Agent': 0.0,
#   'Only If': 0.3,
#   'Sweet Lily Dreams': 0.0,
#   'GALAK-Z': 0.0,
#   "The Beginner's Guide": 0.0,
#   'Trove': 0.1,
#   'Unturned': 58.516666666666666,
#   'Mortal Kombat X': 41.85,
#   'Savage Lands': 0.0,
#   'The Nightmare Cooperative': 0.0,
#   'Call of Duty: Black Ops III': 11.2,
#   'Vertical Drop Heroes HD': 2.2666666666666666,
#   'Enter the Gungeon': 22.75,
#   'Rain World': 0.75,
#   'Pool Nation FX': 0.7333333333333333,
#   'Hazard Ops': 1.75,
#   'Absolute Drift': 0.31666666666666665,
#   "Don't Starve Together": 53.666666666666664,
#   'Tharsis': 0.0,
#   'Grow Home': 0.5166666666666667,
#   'Jotun: Valhalla Edition': 0.0,
#   'TOXIKK': 13.316666666666666,
#   'May’s Mysteries: The Secret of Dragonville': 0.06666666666666667,
#   'Spriter Pro': 0.18333333333333332,
#   'Epic Arena': 1.4,
#   'Runestone Keeper': 0.0,
#   'Particula': 0.016666666666666666,
#   'KHOLAT': 0.0,
#   'Victor Vran': 0.4166666666666667,
#   'ARK: Survival Evolved': 33.3,
#   'NARUTO SHIPPUDEN: Ultimate Ninja STORM 4': 13.9,
#   'Valhalla Hills': 1.5833333333333333,
#   'Styx: Shards of Darkness': 0.0,
#   'Snakebird': 0.0,
#   'Evoland 2': 0.0,
#   "Tom Clancy's Rainbow Six® Siege X": 203.83333333333334,
#   'Uncanny Valley': 0.4166666666666667,
#   'Choice Chamber': 0.2833333333333333,
#   'Remnants of Isolation': 0.0,
#   'Yooka-Laylee': 0.4166666666666667,
#   'Volume': 1.0833333333333333,
#   'No Time To Explain Remastered': 0.5333333333333333,
#   'Ghost in the Shell: Stand Alone Complex - First Assault Online': 1.5333333333333334,
#   'TIS-100': 0.0,
#   'DARK SOULS™ III': 109.65,
#   'Pale Echoes': 0.0,
#   'Fishing Planet': 0.48333333333333334,
#   'Dead by Daylight': 37.233333333333334,
#   'Sakura Clicker': 10.533333333333333,
#   'INK': 0.0,
#   'SMITE': 1.9333333333333333,
#   'Cook, Serve, Delicious! 2!!': 0.0,
#   'Mitos.is: The Game': 1.6833333333333333,
#   'TEKKEN 7': 2.966666666666667,
#   'Acceleration of SUGURI 2': 0.0,
#   'Undertale': 2.05,
#   'Necromonads': 0.0,
#   'Dark Heritage: Guardians of Hope': 0.0,
#   'The Secret Order 2: Masked Intent': 0.0,
#   'Else Heart.Break()': 0.0,
#   'Tabletopia': 0.6666666666666666,
#   'ARK: Survival Of The Fittest': 0.0,
#   'BioShock Remastered': 11.1,
#   'Stardew Valley': 27.55,
#   'Vampire Legends: The True Story of Kisilova': 0.4166666666666667,
#   'Tick Tock Isle': 0.4166666666666667,
#   'Plantera': 0.0,
#   'Devil Daggers': 0.36666666666666664,
#   'Road to Ballhalla': 0.0,
#   'Wallpaper Engine': 27.033333333333335,
#   'Divinity: Original Sin 2': 9.55,
#   'Shadowverse': 2.45,
#   'Deceit': 0.9833333333333333,
#   'Minion Masters': 0.0,
#   'The Elder Scrolls V: Skyrim Special Edition': 3.7,
#   'Battlerite': 48.25,
#   'Last Man Standing': 5.866666666666666,
#   'SCUM': 73.6,
#   'Dear Esther: Landmark Edition': 0.0,
#   'Darwin Project': 3.0166666666666666,
#   'Warhammer: Vermintide 2': 11.866666666666667,
#   'Serious Sam Fusion 2017 (beta)': 0.0,
#   'Golf It!': 8.466666666666667,
#   'PUBG: BATTLEGROUNDS': 348.6666666666667,
#   'Monster Hunter: World': 438.2,
#   'We Were Here': 1.6,
#   'Black Desert': 27.383333333333333,
#   "Tom Clancy's Ghost Recon Wildlands Open Beta": 9.95,
#   'Fallout Shelter': 38.93333333333333,
#   'Ni no Kuni™ II: Revenant Kingdom': 76.65,
#   'Hunt: Showdown 1896': 52.56666666666667,
#   'SOS': 0.0,
#   "Tom Clancy's Rainbow Six Siege - Test Server": 0.0,
#   'Slay the Spire': 60.2,
#   'BattleBit Remastered': 4.833333333333333,
#   'SCP: Secret Laboratory': 0.7833333333333333,
#   'Cube Racer': 13.383333333333333,
#   'Warhammer: Vermintide 2 Closed Test': 1.75,
#   'Phasmophobia': 44.483333333333334,
#   'Temtem': 51.916666666666664,
#   'Hunt: Showdown 1896 (Test Server)': 0.0,
#   "Bear With Me - Collector's Edition": 0.0,
#   'Outward': 35.3,
#   'METAL GEAR SURVIVE BETA': 3.1333333333333333,
#   'SOS: Classic': 0.0,
#   'Radical Heights': 1.9333333333333333,
#   'Realm Royale Reforged': 18.866666666666667,
#   'Totally Accurate Battlegrounds': 0.2,
#   'Noita': 8.35,
#   'CRSED: Cuisine Royale': 2.183333333333333,
#   'Among Us': 19.666666666666668,
#   'Gothic Playable Teaser': 0.0,
#   'Bloons TD 6': 50.13333333333333,
#   'Element TD 2': 6.683333333333334,
#   'Evoland Legendary Edition': 0.0,
#   'New World: Aeternum': 1214.75,
#   'Destiny 2': 2.566666666666667,
#   "Baldur's Gate 3": 107.23333333333333,
#   'Fall Guys': 14.5,
#   'RISK: Global Domination': 2.5833333333333335,
#   'Apex Legends': 82.8,
#   'FINAL FANTASY': 10.533333333333333,
#   'FINAL FANTASY II': 11.266666666666667,
#   'FINAL FANTASY III': 13.433333333333334,
#   'FINAL FANTASY IV': 16.883333333333333,
#   'FINAL FANTASY V': 35.56666666666667,
#   'FINAL FANTASY VI': 31.683333333333334,
#   'Mind Over Magic': 1.3666666666666667,
#   'tModLoader': 102.25,
#   'Loop Hero': 10.25,
#   'SUPERVIVE': 15.116666666666667,
#   'Deadlock': 0.0,
#   'Yu-Gi-Oh!  Master Duel': 132.41666666666666,
#   'IdleOn': 5.383333333333334,
#   'Sker Ritual': 7.066666666666666,
#   'Century Playtest': 0.03333333333333333,
#   'Disney Speedstorm': 2.033333333333333,
#   'NARAKA: BLADEPOINT Playtest': 4.116666666666666,
#   'Lost Ark': 2418.7,
#   'SUPER PEOPLE Testing Grounds': 6.616666666666666,
#   'Palworld': 95.7,
#   'For The King II': 20.8,
#   'New World: Aeternum Open Beta': 0.0,
#   'Crab Game': 1.5833333333333333,
#   'DRAGON BALL: Sparking! ZERO': 19.6,
#   'Lost Ark Closed Technical Beta ': 4.65,
#   'Vampire Survivors': 85.23333333333333,
#   'STALCRAFT: X': 1.8666666666666667,
#   'Monster Hunter Rise: Sunbreak Demo': 0.9,
#   'Call of Duty®': 171.05,
#   'Brotato': 24.183333333333334,
#   'Digimon Story Time Stranger': 71.18333333333334,
#   'MARVEL SNAP': 34.766666666666666,
#   'Soulstone Survivors': 62.2,
#   'Dark and Darker Playtest': 0.5333333333333333,
#   'Unsolved Case': 0.18333333333333332,
#   'Escape Memoirs: Mini Stories': 1.7666666666666666,
#   'What the Fog': 0.0,
#   'Monster Hunter Wilds': 176.95,
#   'Savant - Ascent REMIX': 0.0,
#   'Mind Over Magic Playtest': 14.8,
#   'Black Myth: Wukong': 41.916666666666664,
#   'Balatro': 23.7,
#   'Horizon Forbidden West™ Complete Edition': 24.583333333333332,
#   'SMITE 2': 1.3833333333333333,
#   'Dungeonborne': 37.28333333333333,
#   'Dungeonborne Playtest': 14.583333333333334,
#   "Rusty's Retirement": 95.81666666666666,
#   'Path of Exile 2': 221.45,
#   'Revolution Idle': 198.15,
#   'Content Warning': 6.483333333333333,
#   'Nuclear Nightmare': 3.1166666666666667,
#   'Persona5: The Phantom X': 7.333333333333333,
#   'Monster Hunter Wilds Beta test': 14.366666666666667,
#   'Battlefield™ 6 Open Beta': 6.8,
#   'Temtem: Swarm Playtest': 0.0,
#   'Umamusume: Pretty Derby': 67.48333333333333,
#   'Deadzone Rogue': 17.3,
#   'Megabonk': 49.233333333333334,
#   'Bongo Cat': 198.75,
#   'Gods, Death & Reapers Playtest': 0.0,
#   'Cast n Chill': 6.466666666666667,
#   'PEAK': 8.816666666666666,
#   'King of Meat - Technical Test': 2.066666666666667,
#   'MISERY Playtest': 0.6166666666666667,
#   'Final Sentence Demo': 0.7333333333333333},
#  'imagen_url': {'Counter-Strike': 'https://cdn.cloudflare.steamstatic.com/steam/apps/10/header.jpg',
#   'Day of Defeat': 'https://cdn.cloudflare.steamstatic.com/steam/apps/30/header.jpg',
#   'Deathmatch Classic': 'https://cdn.cloudflare.steamstatic.com/steam/apps/40/header.jpg',
#   'Ricochet': 'https://cdn.cloudflare.steamstatic.com/steam/apps/60/header.jpg',
#   'Counter-Strike: Condition Zero': 'https://cdn.cloudflare.steamstatic.com/steam/apps/80/header.jpg',
#   'Counter-Strike: Condition Zero Deleted Scenes': 'https://cdn.cloudflare.steamstatic.com/steam/apps/100/header.jpg',
#   'Left 4 Dead 2': 'https://cdn.cloudflare.steamstatic.com/steam/apps/550/header.jpg',
#   'Dota 2': 'https://cdn.cloudflare.steamstatic.com/steam/apps/570/header.jpg',
#   'Portal 2': 'https://cdn.cloudflare.steamstatic.com/steam/apps/620/header.jpg',
#   'Counter-Strike 2': 'https://cdn.cloudflare.steamstatic.com/steam/apps/730/header.jpg',
#   'Psychonauts': 'https://cdn.cloudflare.steamstatic.com/steam/apps/3830/header.jpg',
#   "Sid Meier's Civilization IV": 'https://cdn.cloudflare.steamstatic.com/steam/apps/3900/header.jpg',
#   "Sid Meier's Civilization III: Complete": 'https://cdn.cloudflare.steamstatic.com/steam/apps/3910/header.jpg',
#   "Sid Meier's Pirates!": 'https://cdn.cloudflare.steamstatic.com/steam/apps/3920/header.jpg',
#   "Sid Meier's Civilization IV: Warlords": 'https://cdn.cloudflare.steamstatic.com/steam/apps/3990/header.jpg',
#   "Garry's Mod": 'https://cdn.cloudflare.steamstatic.com/steam/apps/4000/header.jpg',
#   'Condemned: Criminal Origins': 'https://cdn.cloudflare.steamstatic.com/steam/apps/4720/header.jpg',
#   'Natural Selection 2': 'https://cdn.cloudflare.steamstatic.com/steam/apps/4920/header.jpg',
#   'Hitman 2: Silent Assassin': 'https://cdn.cloudflare.steamstatic.com/steam/apps/6850/header.jpg',
#   'Hitman: Codename 47': 'https://cdn.cloudflare.steamstatic.com/steam/apps/6900/header.jpg',
#   'X-Blades': 'https://cdn.cloudflare.steamstatic.com/steam/apps/7510/header.jpg',
#   'Two Worlds II HD': 'https://cdn.cloudflare.steamstatic.com/steam/apps/7520/header.jpg',
#   'Two Worlds II Castle Defense': 'https://cdn.cloudflare.steamstatic.com/steam/apps/7530/header.jpg',
#   "Sid Meier's Railroads!": 'https://cdn.cloudflare.steamstatic.com/steam/apps/7600/header.jpg',
#   'BioShock': 'https://cdn.cloudflare.steamstatic.com/steam/apps/7670/header.jpg',
#   'Kane & Lynch: Dead Men': 'https://cdn.cloudflare.steamstatic.com/steam/apps/8080/header.jpg',
#   'Just Cause 2': 'https://cdn.cloudflare.steamstatic.com/steam/apps/8190/header.jpg',
#   "Sid Meier's Civilization IV: Beyond the Sword": 'https://cdn.cloudflare.steamstatic.com/steam/apps/8800/header.jpg',
#   "Sid Meier's Civilization V": 'https://cdn.cloudflare.steamstatic.com/steam/apps/8930/header.jpg',
#   'Saints Row 2': 'https://cdn.cloudflare.steamstatic.com/steam/apps/9480/header.jpg',
#   'Overlord': 'https://cdn.cloudflare.steamstatic.com/steam/apps/11450/header.jpg',
#   'Overlord: Raising Hell': 'https://cdn.cloudflare.steamstatic.com/steam/apps/12710/header.jpg',
#   'Rise of the Argonauts': 'https://cdn.cloudflare.steamstatic.com/steam/apps/12770/header.jpg',
#   'Operation Flashpoint: Dragon Rising': 'https://cdn.cloudflare.steamstatic.com/steam/apps/12830/header.jpg',
#   'AaaaaAAaaaAAAaaAAAAaAAAAA!!! for the Awesome': 'https://cdn.cloudflare.steamstatic.com/steam/apps/15560/header.jpg',
#   "Oddworld: Abe's Oddysee": 'https://cdn.cloudflare.steamstatic.com/steam/apps/15700/header.jpg',
#   'F.E.A.R. 2: Project Origin': 'https://cdn.cloudflare.steamstatic.com/steam/apps/16450/header.jpg',
#   "Sid Meier's Civilization IV: Colonization": 'https://cdn.cloudflare.steamstatic.com/steam/apps/16810/header.jpg',
#   "Mirror's Edge": 'https://cdn.cloudflare.steamstatic.com/steam/apps/17410/header.jpg',
#   'Dead Space (2008)': 'https://cdn.cloudflare.steamstatic.com/steam/apps/17470/header.jpg',
#   'Nuclear Dawn': 'https://cdn.cloudflare.steamstatic.com/steam/apps/17710/header.jpg',
#   'Crazy Machines 2': 'https://cdn.cloudflare.steamstatic.com/steam/apps/18400/header.jpg',
#   'Alice: Madness Returns': 'https://cdn.cloudflare.steamstatic.com/steam/apps/19680/header.jpg',
#   'F.E.A.R.': 'https://cdn.cloudflare.steamstatic.com/steam/apps/21090/header.jpg',
#   'F.E.A.R. 3': 'https://cdn.cloudflare.steamstatic.com/steam/apps/21100/header.jpg',
#   'F.E.A.R.: Extraction Point': 'https://cdn.cloudflare.steamstatic.com/steam/apps/21110/header.jpg',
#   'F.E.A.R.: Perseus Mandate': 'https://cdn.cloudflare.steamstatic.com/steam/apps/21120/header.jpg',
#   'Bionic Commando Rearmed': 'https://cdn.cloudflare.steamstatic.com/steam/apps/21680/header.jpg',
#   'Resident Evil 5': 'https://cdn.cloudflare.steamstatic.com/steam/apps/21690/header.jpg',
#   'Rock of Ages': 'https://cdn.cloudflare.steamstatic.com/steam/apps/22230/header.jpg',
#   'Burnout Paradise: The Ultimate Box': 'https://cdn.cloudflare.steamstatic.com/steam/apps/24740/header.jpg',
#   'Command & Conquer™ Red Alert™ 3 - Uprising': 'https://cdn.cloudflare.steamstatic.com/steam/apps/24800/header.jpg',
#   'Kane & Lynch 2: Dog Days': 'https://cdn.cloudflare.steamstatic.com/steam/apps/28000/header.jpg',
#   'Osmos': 'https://cdn.cloudflare.steamstatic.com/steam/apps/29180/header.jpg',
#   'The Lord of the Rings: War in the North': 'https://cdn.cloudflare.steamstatic.com/steam/apps/32800/header.jpg',
#   'Broken Sword 2 - the Smoking Mirror: Remastered (2010)': 'https://cdn.cloudflare.steamstatic.com/steam/apps/33600/header.jpg',
#   'SEGA Mega Drive & Genesis Classics': 'https://cdn.cloudflare.steamstatic.com/steam/apps/34270/header.jpg',
#   'Mini Ninjas': 'https://cdn.cloudflare.steamstatic.com/steam/apps/35000/header.jpg',
#   'Batman: Arkham Asylum GOTY Edition': 'https://cdn.cloudflare.steamstatic.com/steam/apps/35140/header.jpg',
#   'Rising Storm/Red Orchestra 2 Multiplayer': 'https://cdn.cloudflare.steamstatic.com/steam/apps/35450/header.jpg',
#   'Trine 2': 'https://cdn.cloudflare.steamstatic.com/steam/apps/35720/header.jpg',
#   'RIFT': 'https://cdn.cloudflare.steamstatic.com/steam/apps/39120/header.jpg',
#   'The Guild II': 'https://cdn.cloudflare.steamstatic.com/steam/apps/39650/header.jpg',
#   'The Guild II - Pirates of the European Seas': 'https://cdn.cloudflare.steamstatic.com/steam/apps/39660/header.jpg',
#   'The Guild II: Renaissance': 'https://cdn.cloudflare.steamstatic.com/steam/apps/39680/header.jpg',
#   'Supreme Commander 2': 'https://cdn.cloudflare.steamstatic.com/steam/apps/40100/header.jpg',
#   'Risen': 'https://cdn.cloudflare.steamstatic.com/steam/apps/40300/header.jpg',
#   'Risen 2 - Dark Waters': 'https://cdn.cloudflare.steamstatic.com/steam/apps/40390/header.jpg',
#   'Serious Sam 3: BFE': 'https://cdn.cloudflare.steamstatic.com/steam/apps/41070/header.jpg',
#   'Magicka': 'https://cdn.cloudflare.steamstatic.com/steam/apps/42910/header.jpg',
#   'Metro 2033': 'https://cdn.cloudflare.steamstatic.com/steam/apps/43110/header.jpg',
#   'Metro: Last Light Complete Edition': 'https://cdn.cloudflare.steamstatic.com/steam/apps/43160/header.jpg',
#   'Galcon Fusion': 'https://cdn.cloudflare.steamstatic.com/steam/apps/44200/header.jpg',
#   'Operation Flashpoint: Red River': 'https://cdn.cloudflare.steamstatic.com/steam/apps/44340/header.jpg',
#   'Medal of Honor(TM) Single Player': 'https://cdn.cloudflare.steamstatic.com/steam/apps/47790/header.jpg',
#   'Medal of Honor(TM) Multiplayer': 'https://cdn.cloudflare.steamstatic.com/steam/apps/47830/header.jpg',
#   'Saints Row: The Third': 'https://cdn.cloudflare.steamstatic.com/steam/apps/55230/header.jpg',
#   'Amnesia: The Dark Descent': 'https://cdn.cloudflare.steamstatic.com/steam/apps/57300/header.jpg',
#   'Zen Bound® 2': 'https://cdn.cloudflare.steamstatic.com/steam/apps/61600/header.jpg',
#   'Sniper Elite V2': 'https://cdn.cloudflare.steamstatic.com/steam/apps/63380/header.jpg',
#   'Dustforce': 'https://cdn.cloudflare.steamstatic.com/steam/apps/65300/header.jpg',
#   'Arma: Cold War Assault': 'https://cdn.cloudflare.steamstatic.com/steam/apps/65790/header.jpg',
#   'Dungeon Defenders': 'https://cdn.cloudflare.steamstatic.com/steam/apps/65800/header.jpg',
#   'The Bureau: XCOM Declassified': 'https://cdn.cloudflare.steamstatic.com/steam/apps/65930/header.jpg',
#   'The Darkness II': 'https://cdn.cloudflare.steamstatic.com/steam/apps/67370/header.jpg',
#   'Dino D-Day': 'https://cdn.cloudflare.steamstatic.com/steam/apps/70000/header.jpg',
#   'VVVVVV': 'https://cdn.cloudflare.steamstatic.com/steam/apps/70300/header.jpg',
#   'Worms Ultimate Mayhem': 'https://cdn.cloudflare.steamstatic.com/steam/apps/70600/header.jpg',
#   'Worms Crazy Golf': 'https://cdn.cloudflare.steamstatic.com/steam/apps/70620/header.jpg',
#   'Worms Blast': 'https://cdn.cloudflare.steamstatic.com/steam/apps/70650/header.jpg',
#   'Worms Pinball': 'https://cdn.cloudflare.steamstatic.com/steam/apps/70660/header.jpg',
#   'Star Ruler': 'https://cdn.cloudflare.steamstatic.com/steam/apps/70900/header.jpg',
#   'The Elder Scrolls V: Skyrim': 'https://cdn.cloudflare.steamstatic.com/steam/apps/72850/header.jpg',
#   'Puzzle Bots': 'https://cdn.cloudflare.steamstatic.com/steam/apps/80300/header.jpg',
#   'Dead Island': 'https://cdn.cloudflare.steamstatic.com/steam/apps/91310/header.jpg',
#   'Sanctum': 'https://cdn.cloudflare.steamstatic.com/steam/apps/91600/header.jpg',
#   'Nidhogg': 'https://cdn.cloudflare.steamstatic.com/steam/apps/94400/header.jpg',
#   'Capsized': 'https://cdn.cloudflare.steamstatic.com/steam/apps/95300/header.jpg',
#   'Ravaged Zombie Apocalypse': 'https://cdn.cloudflare.steamstatic.com/steam/apps/96300/header.jpg',
#   'Dungeons of Dredmor': 'https://cdn.cloudflare.steamstatic.com/steam/apps/98800/header.jpg',
#   'Orcs Must Die!': 'https://cdn.cloudflare.steamstatic.com/steam/apps/102600/header.jpg',
#   'Shank 2': 'https://cdn.cloudflare.steamstatic.com/steam/apps/102840/header.jpg',
#   'ORION: Prelude': 'https://cdn.cloudflare.steamstatic.com/steam/apps/104900/header.jpg',
#   'Terraria': 'https://cdn.cloudflare.steamstatic.com/steam/apps/105600/header.jpg',
#   'Project Zomboid': 'https://cdn.cloudflare.steamstatic.com/steam/apps/108600/header.jpg',
#   'Crysis 2 Maximum Edition': 'https://cdn.cloudflare.steamstatic.com/steam/apps/108800/header.jpg',
#   'Blocks That Matter': 'https://cdn.cloudflare.steamstatic.com/steam/apps/111800/header.jpg',
#   'Guardians of Middle-earth': 'https://cdn.cloudflare.steamstatic.com/steam/apps/111900/header.jpg',
#   'Costume Quest': 'https://cdn.cloudflare.steamstatic.com/steam/apps/115100/header.jpg',
#   'Stacking': 'https://cdn.cloudflare.steamstatic.com/steam/apps/115110/header.jpg',
#   'Nosgoth': 'https://cdn.cloudflare.steamstatic.com/steam/apps/200110/header.jpg',
#   'Realm of the Mad God Exalt': 'https://cdn.cloudflare.steamstatic.com/steam/apps/200210/header.jpg',
#   'Batman: Arkham City GOTY': 'https://cdn.cloudflare.steamstatic.com/steam/apps/200260/header.jpg',
#   'Torchlight II': 'https://cdn.cloudflare.steamstatic.com/steam/apps/200710/header.jpg',
#   'Cave Story+': 'https://cdn.cloudflare.steamstatic.com/steam/apps/200900/header.jpg',
#   'Galcon Legends': 'https://cdn.cloudflare.steamstatic.com/steam/apps/201040/header.jpg',
#   'Really Big Sky': 'https://cdn.cloudflare.steamstatic.com/steam/apps/201570/header.jpg',
#   'Orcs Must Die! 2': 'https://cdn.cloudflare.steamstatic.com/steam/apps/201790/header.jpg',
#   'Galactic Civilizations II: Ultimate Edition': 'https://cdn.cloudflare.steamstatic.com/steam/apps/202200/header.jpg',
#   'Hitman: Absolution': 'https://cdn.cloudflare.steamstatic.com/steam/apps/203140/header.jpg',
#   'Titan Attacks': 'https://cdn.cloudflare.steamstatic.com/steam/apps/203210/header.jpg',
#   'Binary Domain': 'https://cdn.cloudflare.steamstatic.com/steam/apps/203750/header.jpg',
#   'Dear Esther': 'https://cdn.cloudflare.steamstatic.com/steam/apps/203810/header.jpg',
#   'Awesomenauts': 'https://cdn.cloudflare.steamstatic.com/steam/apps/204300/header.jpg',
#   'Call of Juarez Gunslinger': 'https://cdn.cloudflare.steamstatic.com/steam/apps/204450/header.jpg',
#   'Retro City Rampage™ DX': 'https://cdn.cloudflare.steamstatic.com/steam/apps/204630/header.jpg',
#   'Lumino City': 'https://cdn.cloudflare.steamstatic.com/steam/apps/205020/header.jpg',
#   'Dishonored': 'https://cdn.cloudflare.steamstatic.com/steam/apps/205100/header.jpg',
#   'Hell Yeah!': 'https://cdn.cloudflare.steamstatic.com/steam/apps/205230/header.jpg',
#   'Mortal Kombat Kollection': 'https://cdn.cloudflare.steamstatic.com/steam/apps/205350/header.jpg',
#   'Insanely Twisted Shadow Planet': 'https://cdn.cloudflare.steamstatic.com/steam/apps/205730/header.jpg',
#   "Tiny and Big: Grandpa's Leftovers": 'https://cdn.cloudflare.steamstatic.com/steam/apps/205910/header.jpg',
#   'Jet Set Radio': 'https://cdn.cloudflare.steamstatic.com/steam/apps/205950/header.jpg',
#   'Gunpoint': 'https://cdn.cloudflare.steamstatic.com/steam/apps/206190/header.jpg',
#   'To the Moon': 'https://cdn.cloudflare.steamstatic.com/steam/apps/206440/header.jpg',
#   '3SwitcheD': 'https://cdn.cloudflare.steamstatic.com/steam/apps/206610/header.jpg',
#   'SpeedRunners': 'https://cdn.cloudflare.steamstatic.com/steam/apps/207140/header.jpg',
#   'Hack, Slash, Loot': 'https://cdn.cloudflare.steamstatic.com/steam/apps/207430/header.jpg',
#   'Symphony': 'https://cdn.cloudflare.steamstatic.com/steam/apps/207750/header.jpg',
#   'Blades of Time': 'https://cdn.cloudflare.steamstatic.com/steam/apps/208670/header.jpg',
#   'Batman™: Arkham Origins': 'https://cdn.cloudflare.steamstatic.com/steam/apps/209000/header.jpg',
#   'Spirits': 'https://cdn.cloudflare.steamstatic.com/steam/apps/210170/header.jpg',
#   'Sanctum 2': 'https://cdn.cloudflare.steamstatic.com/steam/apps/210770/header.jpg',
#   'Battle vs Chess': 'https://cdn.cloudflare.steamstatic.com/steam/apps/211050/header.jpg',
#   'Deadlight': 'https://cdn.cloudflare.steamstatic.com/steam/apps/211400/header.jpg',
#   'DARK SOULS™: Prepare To Die Edition': 'https://cdn.cloudflare.steamstatic.com/steam/apps/211420/header.jpg',
#   'Wanderlust: Rebirth': 'https://cdn.cloudflare.steamstatic.com/steam/apps/211580/header.jpg',
#   'Thief Gold': 'https://cdn.cloudflare.steamstatic.com/steam/apps/211600/header.jpg',
#   'Galaxy on Fire 2™ Full HD': 'https://cdn.cloudflare.steamstatic.com/steam/apps/212010/header.jpg',
#   'TERA': 'https://cdn.cloudflare.steamstatic.com/steam/apps/212740/header.jpg',
#   'Guacamelee! Gold Edition': 'https://cdn.cloudflare.steamstatic.com/steam/apps/214770/header.jpg',
#   'The Incredible Adventures of Van Helsing': 'https://cdn.cloudflare.steamstatic.com/steam/apps/215530/header.jpg',
#   'Dream Pinball 3D': 'https://cdn.cloudflare.steamstatic.com/steam/apps/215790/header.jpg',
#   'Jagged Alliance 2 - Wildfire ': 'https://cdn.cloudflare.steamstatic.com/steam/apps/215930/header.jpg',
#   'BIT.TRIP Presents... Runner2: Future Legend of Rhythm Alien': 'https://cdn.cloudflare.steamstatic.com/steam/apps/218060/header.jpg',
#   'PAYDAY 2': 'https://cdn.cloudflare.steamstatic.com/steam/apps/218620/header.jpg',
#   'Scribblenauts Unlimited': 'https://cdn.cloudflare.steamstatic.com/steam/apps/218680/header.jpg',
#   'Chivalry: Medieval Warfare': 'https://cdn.cloudflare.steamstatic.com/steam/apps/219640/header.jpg',
#   "Don't Starve": 'https://cdn.cloudflare.steamstatic.com/steam/apps/219740/header.jpg',
#   'Antichamber': 'https://cdn.cloudflare.steamstatic.com/steam/apps/219890/header.jpg',
#   'DmC Devil May Cry': 'https://cdn.cloudflare.steamstatic.com/steam/apps/220440/header.jpg',
#   'RPG Maker VX Ace': 'https://cdn.cloudflare.steamstatic.com/steam/apps/220700/header.jpg',
#   'Thomas Was Alone': 'https://cdn.cloudflare.steamstatic.com/steam/apps/220780/header.jpg',
#   'Little Inferno': 'https://cdn.cloudflare.steamstatic.com/steam/apps/221260/header.jpg',
#   'Super Hexagon': 'https://cdn.cloudflare.steamstatic.com/steam/apps/221640/header.jpg',
#   'Resident Evil Revelations': 'https://cdn.cloudflare.steamstatic.com/steam/apps/222480/header.jpg',
#   'Reus': 'https://cdn.cloudflare.steamstatic.com/steam/apps/222730/header.jpg',
#   'Giana Sisters: Twisted Dreams': 'https://cdn.cloudflare.steamstatic.com/steam/apps/223220/header.jpg',
# ...
#   "Jack Orlando Director's Cut": 'https://store.steampowered.com/app/253960',
#   'Enclave': 'https://store.steampowered.com/app/253980',
#   'Commander: Conquest of the Americas Gold': 'https://store.steampowered.com/app/254020',
#   'World War III: Black Gold': 'https://store.steampowered.com/app/254080',
#   'Resident Evil 4 (2005)': 'https://store.steampowered.com/app/254700',
#   'Viscera Cleanup Detail: Shadow Warrior': 'https://store.steampowered.com/app/255520',
#   'Cities: Skylines': 'https://store.steampowered.com/app/255710',
#   'Blast Em!': 'https://store.steampowered.com/app/257630',
#   'Bloody Trapland': 'https://store.steampowered.com/app/257750',
#   'Talisman: Prologue': 'https://store.steampowered.com/app/258200',
#   'Type:Rider': 'https://store.steampowered.com/app/258890',
#   "Montague's Mount": 'https://store.steampowered.com/app/258950',
#   'Heli Heroes': 'https://store.steampowered.com/app/259320',
#   'Chicken Shoot Gold': 'https://store.steampowered.com/app/259340',
#   'Chicken Shoot 2': 'https://store.steampowered.com/app/259360',
#   'Savant - Ascent': 'https://store.steampowered.com/app/259530',
#   '1001 Spikes': 'https://store.steampowered.com/app/260790',
#   'Lethal League': 'https://store.steampowered.com/app/261180',
#   'Dungeons 2': 'https://store.steampowered.com/app/262280',
#   'Alpha Kimori™ Episode One ': 'https://store.steampowered.com/app/265870',
#   'Tower of Guns': 'https://store.steampowered.com/app/266110',
#   'AR-K': 'https://store.steampowered.com/app/269890',
#   'Robot Roller-Derby Disco Dodgeball': 'https://store.steampowered.com/app/270450',
#   'Card City Nights': 'https://store.steampowered.com/app/271820',
#   'Vertiginous Golf': 'https://store.steampowered.com/app/272890',
#   'Counter-Strike Nexon': 'https://store.steampowered.com/app/273110',
#   'Evolve Stage 2': 'https://store.steampowered.com/app/273350',
#   'OlliOlli': 'https://store.steampowered.com/app/274250',
#   'Skara - The Blade Remains': 'https://store.steampowered.com/app/274620',
#   'Guacamelee! Super Turbo Championship Edition': 'https://store.steampowered.com/app/275390',
#   'Skyborn': 'https://store.steampowered.com/app/278460',
#   'Richard & Alice': 'https://store.steampowered.com/app/279260',
#   'The I of the Dragon': 'https://store.steampowered.com/app/279720',
#   "A Wizard's Lizard": 'https://store.steampowered.com/app/280040',
#   'LEGO® The Hobbit™': 'https://store.steampowered.com/app/285160',
#   'RollerCoaster Tycoon 2: Triple Thrill Pack': 'https://store.steampowered.com/app/285330',
#   'Tabletop Simulator': 'https://store.steampowered.com/app/286160',
#   'Metro 2033 Redux': 'https://store.steampowered.com/app/286690',
#   'Resident Evil Revelations 2': 'https://store.steampowered.com/app/287290',
#   'Metro: Last Light Redux': 'https://store.steampowered.com/app/287390',
#   'Brawlhalla': 'https://store.steampowered.com/app/291550',
#   'The Lost Crown': 'https://store.steampowered.com/app/291710',
#   'Never Alone (Kisima Ingitchuna)': 'https://store.steampowered.com/app/295790',
#   'The Great Jitters: Pudding Panic': 'https://store.steampowered.com/app/296650',
#   'Titan Souls': 'https://store.steampowered.com/app/297130',
#   'Spy Chameleon - RGB Agent': 'https://store.steampowered.com/app/297490',
#   'Only If': 'https://store.steampowered.com/app/298260',
#   'Sweet Lily Dreams': 'https://store.steampowered.com/app/300540',
#   'GALAK-Z': 'https://store.steampowered.com/app/300580',
#   "The Beginner's Guide": 'https://store.steampowered.com/app/303210',
#   'Trove': 'https://store.steampowered.com/app/304050',
#   'Unturned': 'https://store.steampowered.com/app/304930',
#   'Mortal Kombat X': 'https://store.steampowered.com/app/307780',
#   'Savage Lands': 'https://store.steampowered.com/app/307880',
#   'The Nightmare Cooperative': 'https://store.steampowered.com/app/310070',
#   'Call of Duty: Black Ops III': 'https://store.steampowered.com/app/311210',
#   'Vertical Drop Heroes HD': 'https://store.steampowered.com/app/311480',
#   'Enter the Gungeon': 'https://store.steampowered.com/app/311690',
#   'Rain World': 'https://store.steampowered.com/app/312520',
#   'Pool Nation FX': 'https://store.steampowered.com/app/314000',
#   'Hazard Ops': 'https://store.steampowered.com/app/319150',
#   'Absolute Drift': 'https://store.steampowered.com/app/320140',
#   "Don't Starve Together": 'https://store.steampowered.com/app/322330',
#   'Tharsis': 'https://store.steampowered.com/app/323060',
#   'Grow Home': 'https://store.steampowered.com/app/323320',
#   'Jotun: Valhalla Edition': 'https://store.steampowered.com/app/323580',
#   'TOXIKK': 'https://store.steampowered.com/app/324810',
#   'May’s Mysteries: The Secret of Dragonville': 'https://store.steampowered.com/app/327650',
#   'Spriter Pro': 'https://store.steampowered.com/app/332360',
#   'Epic Arena': 'https://store.steampowered.com/app/334030',
#   'Runestone Keeper': 'https://store.steampowered.com/app/339400',
#   'Particula': 'https://store.steampowered.com/app/343360',
#   'KHOLAT': 'https://store.steampowered.com/app/343710',
#   'Victor Vran': 'https://store.steampowered.com/app/345180',
#   'ARK: Survival Evolved': 'https://store.steampowered.com/app/346110',
#   'NARUTO SHIPPUDEN: Ultimate Ninja STORM 4': 'https://store.steampowered.com/app/349040',
#   'Valhalla Hills': 'https://store.steampowered.com/app/351910',
#   'Styx: Shards of Darkness': 'https://store.steampowered.com/app/355790',
#   'Snakebird': 'https://store.steampowered.com/app/357300',
#   'Evoland 2': 'https://store.steampowered.com/app/359310',
#   "Tom Clancy's Rainbow Six® Siege X": 'https://store.steampowered.com/app/359550',
#   'Uncanny Valley': 'https://store.steampowered.com/app/359580',
#   'Choice Chamber': 'https://store.steampowered.com/app/359960',
#   'Remnants of Isolation': 'https://store.steampowered.com/app/360010',
#   'Yooka-Laylee': 'https://store.steampowered.com/app/360830',
#   'Volume': 'https://store.steampowered.com/app/365770',
#   'No Time To Explain Remastered': 'https://store.steampowered.com/app/368730',
#   'Ghost in the Shell: Stand Alone Complex - First Assault Online': 'https://store.steampowered.com/app/369200',
#   'TIS-100': 'https://store.steampowered.com/app/370360',
#   'DARK SOULS™ III': 'https://store.steampowered.com/app/374320',
#   'Pale Echoes': 'https://store.steampowered.com/app/377190',
#   'Fishing Planet': 'https://store.steampowered.com/app/380600',
#   'Dead by Daylight': 'https://store.steampowered.com/app/381210',
#   'Sakura Clicker': 'https://store.steampowered.com/app/383080',
#   'INK': 'https://store.steampowered.com/app/385710',
#   'SMITE': 'https://store.steampowered.com/app/386360',
#   'Cook, Serve, Delicious! 2!!': 'https://store.steampowered.com/app/386620',
#   'Mitos.is: The Game': 'https://store.steampowered.com/app/389570',
#   'TEKKEN 7': 'https://store.steampowered.com/app/389730',
#   'Acceleration of SUGURI 2': 'https://store.steampowered.com/app/390710',
#   'Undertale': 'https://store.steampowered.com/app/391540',
#   'Necromonads': 'https://store.steampowered.com/app/391630',
#   'Dark Heritage: Guardians of Hope': 'https://store.steampowered.com/app/394280',
#   'The Secret Order 2: Masked Intent': 'https://store.steampowered.com/app/399890',
#   'Else Heart.Break()': 'https://store.steampowered.com/app/400110',
#   'Tabletopia': 'https://store.steampowered.com/app/402560',
#   'ARK: Survival Of The Fittest': 'https://store.steampowered.com/app/407530',
#   'BioShock Remastered': 'https://store.steampowered.com/app/409710',
#   'Stardew Valley': 'https://store.steampowered.com/app/413150',
#   'Vampire Legends: The True Story of Kisilova': 'https://store.steampowered.com/app/414660',
#   'Tick Tock Isle': 'https://store.steampowered.com/app/418440',
#   'Plantera': 'https://store.steampowered.com/app/421040',
#   'Devil Daggers': 'https://store.steampowered.com/app/422970',
#   'Road to Ballhalla': 'https://store.steampowered.com/app/425410',
#   'Wallpaper Engine': 'https://store.steampowered.com/app/431960',
#   'Divinity: Original Sin 2': 'https://store.steampowered.com/app/435150',
#   'Shadowverse': 'https://store.steampowered.com/app/453480',
#   'Deceit': 'https://store.steampowered.com/app/466240',
#   'Minion Masters': 'https://store.steampowered.com/app/489520',
#   'The Elder Scrolls V: Skyrim Special Edition': 'https://store.steampowered.com/app/489830',
#   'Battlerite': 'https://store.steampowered.com/app/504370',
#   'Last Man Standing': 'https://store.steampowered.com/app/506540',
#   'SCUM': 'https://store.steampowered.com/app/513710',
#   'Dear Esther: Landmark Edition': 'https://store.steampowered.com/app/520720',
#   'Darwin Project': 'https://store.steampowered.com/app/544920',
#   'Warhammer: Vermintide 2': 'https://store.steampowered.com/app/552500',
#   'Serious Sam Fusion 2017 (beta)': 'https://store.steampowered.com/app/564310',
#   'Golf It!': 'https://store.steampowered.com/app/571740',
#   'PUBG: BATTLEGROUNDS': 'https://store.steampowered.com/app/578080',
#   'Monster Hunter: World': 'https://store.steampowered.com/app/582010',
#   'We Were Here': 'https://store.steampowered.com/app/582500',
#   'Black Desert': 'https://store.steampowered.com/app/582660',
#   "Tom Clancy's Ghost Recon Wildlands Open Beta": 'https://store.steampowered.com/app/584210',
#   'Fallout Shelter': 'https://store.steampowered.com/app/588430',
#   'Ni no Kuni™ II: Revenant Kingdom': 'https://store.steampowered.com/app/589360',
#   'Hunt: Showdown 1896': 'https://store.steampowered.com/app/594650',
#   'SOS': 'https://store.steampowered.com/app/619080',
#   "Tom Clancy's Rainbow Six Siege - Test Server": 'https://store.steampowered.com/app/623990',
#   'Slay the Spire': 'https://store.steampowered.com/app/646570',
#   'BattleBit Remastered': 'https://store.steampowered.com/app/671860',
#   'SCP: Secret Laboratory': 'https://store.steampowered.com/app/700330',
#   'Cube Racer': 'https://store.steampowered.com/app/705210',
#   'Warhammer: Vermintide 2 Closed Test': 'https://store.steampowered.com/app/737010',
#   'Phasmophobia': 'https://store.steampowered.com/app/739630',
#   'Temtem': 'https://store.steampowered.com/app/745920',
#   'Hunt: Showdown 1896 (Test Server)': 'https://store.steampowered.com/app/770720',
#   "Bear With Me - Collector's Edition": 'https://store.steampowered.com/app/783050',
#   'Outward': 'https://store.steampowered.com/app/794260',
#   'METAL GEAR SURVIVE BETA': 'https://store.steampowered.com/app/797470',
#   'SOS: Classic': 'https://store.steampowered.com/app/802240',
#   'Radical Heights': 'https://store.steampowered.com/app/809960',
#   'Realm Royale Reforged': 'https://store.steampowered.com/app/813820',
#   'Totally Accurate Battlegrounds': 'https://store.steampowered.com/app/823130',
#   'Noita': 'https://store.steampowered.com/app/881100',
#   'CRSED: Cuisine Royale': 'https://store.steampowered.com/app/884660',
#   'Among Us': 'https://store.steampowered.com/app/945360',
#   'Gothic Playable Teaser': 'https://store.steampowered.com/app/950670',
#   'Bloons TD 6': 'https://store.steampowered.com/app/960090',
#   'Element TD 2': 'https://store.steampowered.com/app/1018830',
#   'Evoland Legendary Edition': 'https://store.steampowered.com/app/1020470',
#   'New World: Aeternum': 'https://store.steampowered.com/app/1063730',
#   'Destiny 2': 'https://store.steampowered.com/app/1085660',
#   "Baldur's Gate 3": 'https://store.steampowered.com/app/1086940',
#   'Fall Guys': 'https://store.steampowered.com/app/1097150',
#   'RISK: Global Domination': 'https://store.steampowered.com/app/1128810',
#   'Apex Legends': 'https://store.steampowered.com/app/1172470',
#   'FINAL FANTASY': 'https://store.steampowered.com/app/1173770',
#   'FINAL FANTASY II': 'https://store.steampowered.com/app/1173780',
#   'FINAL FANTASY III': 'https://store.steampowered.com/app/1173790',
#   'FINAL FANTASY IV': 'https://store.steampowered.com/app/1173800',
#   'FINAL FANTASY V': 'https://store.steampowered.com/app/1173810',
#   'FINAL FANTASY VI': 'https://store.steampowered.com/app/1173820',
#   'Mind Over Magic': 'https://store.steampowered.com/app/1270580',
#   'tModLoader': 'https://store.steampowered.com/app/1281930',
#   'Loop Hero': 'https://store.steampowered.com/app/1282730',
#   'SUPERVIVE': 'https://store.steampowered.com/app/1283700',
#   'Deadlock': 'https://store.steampowered.com/app/1422450',
#   'Yu-Gi-Oh!  Master Duel': 'https://store.steampowered.com/app/1449850',
#   'IdleOn': 'https://store.steampowered.com/app/1476970',
#   'Sker Ritual': 'https://store.steampowered.com/app/1492070',
#   'Century Playtest': 'https://store.steampowered.com/app/1492330',
#   'Disney Speedstorm': 'https://store.steampowered.com/app/1537830',
#   'NARAKA: BLADEPOINT Playtest': 'https://store.steampowered.com/app/1584640',
#   'Lost Ark': 'https://store.steampowered.com/app/1599340',
#   'SUPER PEOPLE Testing Grounds': 'https://store.steampowered.com/app/1619990',
#   'Palworld': 'https://store.steampowered.com/app/1623730',
#   'For The King II': 'https://store.steampowered.com/app/1676840',
#   'New World: Aeternum Open Beta': 'https://store.steampowered.com/app/1724660',
#   'Crab Game': 'https://store.steampowered.com/app/1782210',
#   'DRAGON BALL: Sparking! ZERO': 'https://store.steampowered.com/app/1790600',
#   'Lost Ark Closed Technical Beta ': 'https://store.steampowered.com/app/1793660',
#   'Vampire Survivors': 'https://store.steampowered.com/app/1794680',
#   'STALCRAFT: X': 'https://store.steampowered.com/app/1818450',
#   'Monster Hunter Rise: Sunbreak Demo': 'https://store.steampowered.com/app/1836450',
#   'Call of Duty®': 'https://store.steampowered.com/app/1938090',
#   'Brotato': 'https://store.steampowered.com/app/1942280',
#   'Digimon Story Time Stranger': 'https://store.steampowered.com/app/1984270',
#   'MARVEL SNAP': 'https://store.steampowered.com/app/1997040',
#   'Soulstone Survivors': 'https://store.steampowered.com/app/2066020',
#   'Dark and Darker Playtest': 'https://store.steampowered.com/app/2078890',
#   'Unsolved Case': 'https://store.steampowered.com/app/2084050',
#   'Escape Memoirs: Mini Stories': 'https://store.steampowered.com/app/2098350',
#   'What the Fog': 'https://store.steampowered.com/app/2139020',
#   'Monster Hunter Wilds': 'https://store.steampowered.com/app/2246340',
#   'Savant - Ascent REMIX': 'https://store.steampowered.com/app/2279330',
#   'Mind Over Magic Playtest': 'https://store.steampowered.com/app/2354320',
#   'Black Myth: Wukong': 'https://store.steampowered.com/app/2358720',
#   'Balatro': 'https://store.steampowered.com/app/2379780',
#   'Horizon Forbidden West™ Complete Edition': 'https://store.steampowered.com/app/2420110',
#   'SMITE 2': 'https://store.steampowered.com/app/2437170',
#   'Dungeonborne': 'https://store.steampowered.com/app/2448970',
#   'Dungeonborne Playtest': 'https://store.steampowered.com/app/2452260',
#   "Rusty's Retirement": 'https://store.steampowered.com/app/2666510',
#   'Path of Exile 2': 'https://store.steampowered.com/app/2694490',
#   'Revolution Idle': 'https://store.steampowered.com/app/2763740',
#   'Content Warning': 'https://store.steampowered.com/app/2881650',
#   'Nuclear Nightmare': 'https://store.steampowered.com/app/2909110',
#   'Persona5: The Phantom X': 'https://store.steampowered.com/app/3061570',
#   'Monster Hunter Wilds Beta test': 'https://store.steampowered.com/app/3065170',
#   'Battlefield™ 6 Open Beta': 'https://store.steampowered.com/app/3081410',
#   'Temtem: Swarm Playtest': 'https://store.steampowered.com/app/3101950',
#   'Umamusume: Pretty Derby': 'https://store.steampowered.com/app/3224770',
#   'Deadzone Rogue': 'https://store.steampowered.com/app/3228590',
#   'Megabonk': 'https://store.steampowered.com/app/3405340',
#   'Bongo Cat': 'https://store.steampowered.com/app/3419430',
#   'Gods, Death & Reapers Playtest': 'https://store.steampowered.com/app/3475870',
#   'Cast n Chill': 'https://store.steampowered.com/app/3483740',
#   'PEAK': 'https://store.steampowered.com/app/3527290',
#   'King of Meat - Technical Test': 'https://store.steampowered.com/app/3560320',
#   'MISERY Playtest': 'https://store.steampowered.com/app/3847130',
#   'Final Sentence Demo': 'https://store.steampowered.com/app/4021860'}}

# %% [markdown]
# ------------------------------------

# %% [markdown]
# ------------------------------------

# %%
# Crear un dataframe de juegos_rawg.db
from rawg_api_scraper_reintentos import obtener_dataframe_juegos
df_rawg = obtener_dataframe_juegos()
df_rawg
# Out:
#             id                          name  \
# 0            1               D/Generation HD
# 1            2              Extreme Exorcism
# 2            3            Toto Temple Deluxe
# 3            4                      Penarium
# 4            5                    Standpoint
# ...        ...                           ...
# 99068  1015265  Loutra: Inaugural Group Show
# 99069  1015266                   プレイすると死ぬゲーム
# 99070  1015267            Stay in the rhythm
# 99071  1015268                    Mazebreach
# 99072  1015269                  Gatestriders
#
#                                         background_image  metacritic  \
# 0      https://media.rawg.io/media/screenshots/5c4/5c...         NaN
# 1      https://media.rawg.io/media/screenshots/67d/67...        75.0
# 2      https://media.rawg.io/media/screenshots/0af/0a...         NaN
# 3      https://media.rawg.io/media/screenshots/68b/68...        80.0
# 4      https://media.rawg.io/media/screenshots/238/23...         NaN
# ...                                                  ...         ...
# 99068  https://media.rawg.io/media/screenshots/c42/c4...         NaN
# 99069  https://media.rawg.io/media/screenshots/4b6/4b...         NaN
# 99070  https://media.rawg.io/media/screenshots/9fd/9f...         NaN
# 99071  https://media.rawg.io/media/screenshots/919/91...         NaN
# 99072  https://media.rawg.io/media/screenshots/a89/a8...         NaN
#
#        steam_store_id                            genres  \
# 0               19827                 Adventure, Puzzle
# 1               18705  Action, Adventure, Casual, Indie
# 2               23421             Action, Casual, Indie
# 3               19765     Action, Arcade, Casual, Indie
# 4               25258                     Action, Indie
# ...               ...                               ...
# 99068         1017113    RPG, Simulation, Casual, Indie
# 99069         1017114                             Indie
# 99070         1017115                     Action, Indie
# 99071         1017116                            Action
# 99072         1017117                     Casual, Indie
#
#                                                     tags     fecha_extraccion
# 0      Singleplayer, Steam Achievements, Full control...  2025-11-25 14:05:45
# 1      Singleplayer, Steam Achievements, Multiplayer,...  2025-11-25 13:59:13
# 2      Singleplayer, Steam Achievements, Multiplayer,...  2025-11-25 14:06:44
# 3      Singleplayer, Steam Achievements, Full control...  2025-11-25 13:58:02
# 4      Singleplayer, Steam Achievements, Full control...  2025-11-25 14:16:44
# ...                                                  ...                  ...
# 99068  Singleplayer, Steam Achievements, Atmospheric,...  2025-11-25 15:38:02
# 99069  Singleplayer, 2D, Horror, 3D, Walking Simulato...  2025-11-25 15:38:02
# 99070  Singleplayer, Steam Achievements, Steam Cloud,...  2025-11-25 15:38:02
# 99071  Singleplayer, Stealth, Survival Horror, VR, Fa...  2025-11-25 15:38:02
# 99072  Singleplayer, 2D, Female Protagonist, Pixel Gr...  2025-11-25 15:38:02
#
# [99073 rows x 8 columns]

# %%
# Eliminamos las columnas que no nos interesan
df_rawg = df_rawg.drop(columns=['fecha_extraccion', 'id', 'tags', 'metacritic', 'steam_store_id' ])

# %%
df_rawg
# Out:
#                                name  \
# 0                   D/Generation HD
# 1                  Extreme Exorcism
# 2                Toto Temple Deluxe
# 3                          Penarium
# 4                        Standpoint
# ...                             ...
# 99068  Loutra: Inaugural Group Show
# 99069                   プレイすると死ぬゲーム
# 99070            Stay in the rhythm
# 99071                    Mazebreach
# 99072                  Gatestriders
#
#                                         background_image  \
# 0      https://media.rawg.io/media/screenshots/5c4/5c...
# 1      https://media.rawg.io/media/screenshots/67d/67...
# 2      https://media.rawg.io/media/screenshots/0af/0a...
# 3      https://media.rawg.io/media/screenshots/68b/68...
# 4      https://media.rawg.io/media/screenshots/238/23...
# ...                                                  ...
# 99068  https://media.rawg.io/media/screenshots/c42/c4...
# 99069  https://media.rawg.io/media/screenshots/4b6/4b...
# 99070  https://media.rawg.io/media/screenshots/9fd/9f...
# 99071  https://media.rawg.io/media/screenshots/919/91...
# 99072  https://media.rawg.io/media/screenshots/a89/a8...
#
#                                  genres
# 0                     Adventure, Puzzle
# 1      Action, Adventure, Casual, Indie
# 2                 Action, Casual, Indie
# 3         Action, Arcade, Casual, Indie
# 4                         Action, Indie
# ...                                 ...
# 99068    RPG, Simulation, Casual, Indie
# 99069                             Indie
# 99070                     Action, Indie
# 99071                            Action
# 99072                     Casual, Indie
#
# [99073 rows x 3 columns]

# %% [markdown]
# ------------------------------------

# %% [markdown]
# ------------------------------------

# %%
# Creamos un dataframe de steam_data.db
from SteamSpy import obtener_dataframe_steam_data
df_steam_spy = obtener_dataframe_steam_data()
df_steam_spy
# Out:
#          appid                              name             developer  \
# 0          730  Counter-Strike: Global Offensive                 Valve
# 1      1172470                      Apex Legends               Respawn
# 2       578080               PUBG: BATTLEGROUNDS      PUBG Corporation
# 3      1623730                          Palworld            Pocketpair
# 4          440                   Team Fortress 2                 Valve
# ...        ...                               ...                   ...
# 86536  2571600                Meurtre Au Florian      Nikoballz, PnDAa
# 86537  3223680     Rescue Girl Operation: Code X            2024-NGame
# 86538  3310110                  Big Burger Tower  Frozen Logic Studios
# 86539  1589920           Long Ago: A Puzzle Tale             GrimTalin
# 86540  1513670                              Fono             Fono Labs
#
#                   publisher score_rank positive negative userscore  \
# 0                     Valve             7642084  1173003         0
# 1           Electronic Arts              668053   326926         0
# 2             KRAFTON, Inc.             1520457  1037487         0
# 3                Pocketpair              358266    22443         0
# 4                     Valve             1044264   117208         0
# ...                     ...        ...      ...      ...       ...
# 86536             Nikoballz                   7        2         0
# 86537            2024-NGame                   1        1         0
# 86538  Frozen Logic Studios                   2        1         0
# 86539             GrimTalin                  15        2         0
# 86540             Fono Labs                  17        0         0
#
#                            owners average_forever average_2weeks  \
# 0      100,000,000 .. 200,000,000           33076            731
# 1      100,000,000 .. 200,000,000           10632            622
# 2      100,000,000 .. 200,000,000           23472            855
# 3       50,000,000 .. 100,000,000            3799            689
# 4       50,000,000 .. 100,000,000           23714            330
# ...                           ...             ...            ...
# 86536                 0 .. 20,000               0              0
# 86537                 0 .. 20,000               0              0
# 86538                 0 .. 20,000               0              0
# 86539                 0 .. 20,000               0              0
# 86540                 0 .. 20,000               0              0
#
#       median_forever median_2weeks price initialprice discount      ccu
# 0               6137           295     0            0        0  1013936
# 1                962           250     0            0        0   124262
# 2               6057           316     0            0        0   314682
# 3               2202           219  2999         2999        0    18028
# 4               4326            89     0            0        0    43819
# ...              ...           ...   ...          ...      ...      ...
# 86536              0             0   499          499        0        0
# 86537              0             0   399          399        0        0
# 86538              0             0   399          399        0        0
# 86539              0             0   499          499        0        0
# 86540              0             0   599          599        0        0
#
# [86541 rows x 17 columns]

# %%
# Nos quedamos solo con las columnas de interés 
columnas_interes_steam_spy = ['appid','name','positive','negative', 'owners', 'initialprice']
df_steam_spy_interes = df_steam_spy[columnas_interes_steam_spy]
df_steam_spy_interes
# Out:
#          appid                              name positive negative  \
# 0          730  Counter-Strike: Global Offensive  7642084  1173003
# 1      1172470                      Apex Legends   668053   326926
# 2       578080               PUBG: BATTLEGROUNDS  1520457  1037487
# 3      1623730                          Palworld   358266    22443
# 4          440                   Team Fortress 2  1044264   117208
# ...        ...                               ...      ...      ...
# 86536  2571600                Meurtre Au Florian        7        2
# 86537  3223680     Rescue Girl Operation: Code X        1        1
# 86538  3310110                  Big Burger Tower        2        1
# 86539  1589920           Long Ago: A Puzzle Tale       15        2
# 86540  1513670                              Fono       17        0
#
#                            owners initialprice
# 0      100,000,000 .. 200,000,000            0
# 1      100,000,000 .. 200,000,000            0
# 2      100,000,000 .. 200,000,000            0
# 3       50,000,000 .. 100,000,000         2999
# 4       50,000,000 .. 100,000,000            0
# ...                           ...          ...
# 86536                 0 .. 20,000          499
# 86537                 0 .. 20,000          399
# 86538                 0 .. 20,000          399
# 86539                 0 .. 20,000          499
# 86540                 0 .. 20,000          599
#
# [86541 rows x 6 columns]

# %%
# Reemplazamos los las filas que contengan el string None de la columna price por NaN
df_steam_spy_interes['initialprice'] = df_steam_spy_interes['initialprice'].replace('None', np.nan)
# Out:
# C:\Users\Metal\AppData\Local\Temp\ipykernel_42572\965189360.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_steam_spy_interes['initialprice'] = df_steam_spy_interes['initialprice'].replace('None', np.nan)

# %%
# Borramos las filas con precios nulos ya que son muy pocas
df_steam_spy_interes = df_steam_spy_interes.dropna(subset=['initialprice'])
#df_steam_spy_interes.shape

# %% [markdown]
# ------------------------------------

# %% [markdown]
# ------------------------------------

# %%
# combinar los dataset df_steam_spy y df_rawg_filtrado usando la columna name
df_combinado = pd.merge(df_steam_spy_interes, df_rawg, left_on='name', right_on='name', how='inner')
df_combinado.shape
# Out:
# (62012, 8)

# %%
df_combinado
# Out:
#          appid                              name positive negative  \
# 0          730  Counter-Strike: Global Offensive  7642084  1173003
# 1      1172470                      Apex Legends   668053   326926
# 2      1623730                          Palworld   358266    22443
# 3          440                   Team Fortress 2  1044264   117208
# 4      1938090   Call of Duty: Modern Warfare II   419594   294520
# ...        ...                               ...      ...      ...
# 62007  2571600                Meurtre Au Florian        7        2
# 62008  3223680     Rescue Girl Operation: Code X        1        1
# 62009  3310110                  Big Burger Tower        2        1
# 62010  1589920           Long Ago: A Puzzle Tale       15        2
# 62011  1513670                              Fono       17        0
#
#                            owners initialprice  \
# 0      100,000,000 .. 200,000,000            0
# 1      100,000,000 .. 200,000,000            0
# 2       50,000,000 .. 100,000,000         2999
# 3       50,000,000 .. 100,000,000            0
# 4       50,000,000 .. 100,000,000         6999
# ...                           ...          ...
# 62007                 0 .. 20,000          499
# 62008                 0 .. 20,000          399
# 62009                 0 .. 20,000          399
# 62010                 0 .. 20,000          499
# 62011                 0 .. 20,000          599
#
#                                         background_image  \
# 0      https://media.rawg.io/media/games/736/73619bd3...
# 1      https://media.rawg.io/media/games/737/737ea566...
# 2      https://media.rawg.io/media/games/4e9/4e9c9514...
# 3      https://media.rawg.io/media/games/46d/46d98e69...
# 4      https://media.rawg.io/media/games/1af/1af8edc7...
# ...                                                  ...
# 62007  https://media.rawg.io/media/screenshots/9bb/9b...
# 62008  https://media.rawg.io/media/screenshots/ccd/cc...
# 62009  https://media.rawg.io/media/screenshots/8f1/8f...
# 62010  https://media.rawg.io/media/screenshots/73e/73...
# 62011  https://media.rawg.io/media/screenshots/e96/e9...
#
#                               genres
# 0                            Shooter
# 1                    Action, Shooter
# 2      Action, Adventure, RPG, Indie
# 3                    Action, Shooter
# 4                    Action, Shooter
# ...                              ...
# 62007               Adventure, Indie
# 62008                      Adventure
# 62009             Simulation, Casual
# 62010                          Indie
# 62011                  Casual, Indie
#
# [62012 rows x 8 columns]

# %%
# Cambiamos la columna 'initialprice' a tipo int y las cambiamos a euros

df_combinado['initialprice'] = df_combinado['initialprice'].astype(int) / 100

# %%
df_combinado
# Out:
#          appid                              name positive negative  \
# 0          730  Counter-Strike: Global Offensive  7642084  1173003
# 1      1172470                      Apex Legends   668053   326926
# 2      1623730                          Palworld   358266    22443
# 3          440                   Team Fortress 2  1044264   117208
# 4      1938090   Call of Duty: Modern Warfare II   419594   294520
# ...        ...                               ...      ...      ...
# 62010  2571600                Meurtre Au Florian        7        2
# 62011  3223680     Rescue Girl Operation: Code X        1        1
# 62012  3310110                  Big Burger Tower        2        1
# 62013  1589920           Long Ago: A Puzzle Tale       15        2
# 62014  1513670                              Fono       17        0
#
#                            owners  \
# 0      100,000,000 .. 200,000,000
# 1      100,000,000 .. 200,000,000
# 2       50,000,000 .. 100,000,000
# 3       50,000,000 .. 100,000,000
# 4       50,000,000 .. 100,000,000
# ...                           ...
# 62010                 0 .. 20,000
# 62011                 0 .. 20,000
# 62012                 0 .. 20,000
# 62013                 0 .. 20,000
# 62014                 0 .. 20,000
#
#                                         background_image  \
# 0      https://media.rawg.io/media/games/736/73619bd3...
# 1      https://media.rawg.io/media/games/737/737ea566...
# 2      https://media.rawg.io/media/games/4e9/4e9c9514...
# 3      https://media.rawg.io/media/games/46d/46d98e69...
# 4      https://media.rawg.io/media/games/1af/1af8edc7...
# ...                                                  ...
# 62010  https://media.rawg.io/media/screenshots/9bb/9b...
# 62011  https://media.rawg.io/media/screenshots/ccd/cc...
# 62012  https://media.rawg.io/media/screenshots/8f1/8f...
# 62013  https://media.rawg.io/media/screenshots/73e/73...
# 62014  https://media.rawg.io/media/screenshots/e96/e9...
#
#                               genres
# 0                            Shooter
# 1                    Action, Shooter
# 2      Action, Adventure, RPG, Indie
# 3                    Action, Shooter
# 4                    Action, Shooter
# ...                              ...
# 62010               Adventure, Indie
# 62011                      Adventure
# 62012             Simulation, Casual
# 62013                          Indie
# 62014                  Casual, Indie
#
# [62015 rows x 7 columns]

# %%
# Sacamos un porcentaje de votos positivos enbase a las columnas positive y negative y los dejamos con dos decimales
df_combinado['porcentaje_votos_positivos'] = (df_combinado['positive'].astype(float) / (df_combinado['positive'].astype(float) + df_combinado['negative'].astype(float)) * 100).round(2)
df_combinado
# Out:
#          appid                              name positive negative  \
# 0          730  Counter-Strike: Global Offensive  7642084  1173003
# 1      1172470                      Apex Legends   668053   326926
# 2      1623730                          Palworld   358266    22443
# 3          440                   Team Fortress 2  1044264   117208
# 4      1938090   Call of Duty: Modern Warfare II   419594   294520
# ...        ...                               ...      ...      ...
# 62007  2571600                Meurtre Au Florian        7        2
# 62008  3223680     Rescue Girl Operation: Code X        1        1
# 62009  3310110                  Big Burger Tower        2        1
# 62010  1589920           Long Ago: A Puzzle Tale       15        2
# 62011  1513670                              Fono       17        0
#
#                            owners  initialprice  \
# 0      100,000,000 .. 200,000,000          0.00
# 1      100,000,000 .. 200,000,000          0.00
# 2       50,000,000 .. 100,000,000         29.99
# 3       50,000,000 .. 100,000,000          0.00
# 4       50,000,000 .. 100,000,000         69.99
# ...                           ...           ...
# 62007                 0 .. 20,000          4.99
# 62008                 0 .. 20,000          3.99
# 62009                 0 .. 20,000          3.99
# 62010                 0 .. 20,000          4.99
# 62011                 0 .. 20,000          5.99
#
#                                         background_image  \
# 0      https://media.rawg.io/media/games/736/73619bd3...
# 1      https://media.rawg.io/media/games/737/737ea566...
# 2      https://media.rawg.io/media/games/4e9/4e9c9514...
# 3      https://media.rawg.io/media/games/46d/46d98e69...
# 4      https://media.rawg.io/media/games/1af/1af8edc7...
# ...                                                  ...
# 62007  https://media.rawg.io/media/screenshots/9bb/9b...
# 62008  https://media.rawg.io/media/screenshots/ccd/cc...
# 62009  https://media.rawg.io/media/screenshots/8f1/8f...
# 62010  https://media.rawg.io/media/screenshots/73e/73...
# 62011  https://media.rawg.io/media/screenshots/e96/e9...
#
#                               genres  porcentaje_votos_positivos
# 0                            Shooter                       86.69
# 1                    Action, Shooter                       67.14
# 2      Action, Adventure, RPG, Indie                       94.10
# 3                    Action, Shooter                       89.91
# 4                    Action, Shooter                       58.76
# ...                              ...                         ...
# 62007               Adventure, Indie                       77.78
# 62008                      Adventure                       50.00
# 62009             Simulation, Casual                       66.67
# 62010                          Indie                       88.24
# 62011                  Casual, Indie                      100.00
#
# [62012 rows x 9 columns]

# %%
# Cambiamos los datos de la columna 'owners' para que en vez de un rango de personas que tienen el juego, tengamos un valor numérico que sea la media del rango. Por ejemplo si el campo contiene '500,000 .. 1,000,000' lo cambiariamos a 750000
def calcular_media_owners(rango):
    partes = rango.split(' .. ')
    if len(partes) == 2:
        min_owners = int(partes[0].replace(',', ''))
        max_owners = int(partes[1].replace(',', ''))
        return (min_owners + max_owners) // 2
    return np.nan
df_combinado['owners'] = df_combinado['owners'].apply(calcular_media_owners)
df_combinado
# Out:
#          appid                              name positive negative     owners  \
# 0          730  Counter-Strike: Global Offensive  7642084  1173003  150000000
# 1      1172470                      Apex Legends   668053   326926  150000000
# 2      1623730                          Palworld   358266    22443   75000000
# 3          440                   Team Fortress 2  1044264   117208   75000000
# 4      1938090   Call of Duty: Modern Warfare II   419594   294520   75000000
# ...        ...                               ...      ...      ...        ...
# 62007  2571600                Meurtre Au Florian        7        2      10000
# 62008  3223680     Rescue Girl Operation: Code X        1        1      10000
# 62009  3310110                  Big Burger Tower        2        1      10000
# 62010  1589920           Long Ago: A Puzzle Tale       15        2      10000
# 62011  1513670                              Fono       17        0      10000
#
#        initialprice                                   background_image  \
# 0              0.00  https://media.rawg.io/media/games/736/73619bd3...
# 1              0.00  https://media.rawg.io/media/games/737/737ea566...
# 2             29.99  https://media.rawg.io/media/games/4e9/4e9c9514...
# 3              0.00  https://media.rawg.io/media/games/46d/46d98e69...
# 4             69.99  https://media.rawg.io/media/games/1af/1af8edc7...
# ...             ...                                                ...
# 62007          4.99  https://media.rawg.io/media/screenshots/9bb/9b...
# 62008          3.99  https://media.rawg.io/media/screenshots/ccd/cc...
# 62009          3.99  https://media.rawg.io/media/screenshots/8f1/8f...
# 62010          4.99  https://media.rawg.io/media/screenshots/73e/73...
# 62011          5.99  https://media.rawg.io/media/screenshots/e96/e9...
#
#                               genres  porcentaje_votos_positivos
# 0                            Shooter                       86.69
# 1                    Action, Shooter                       67.14
# 2      Action, Adventure, RPG, Indie                       94.10
# 3                    Action, Shooter                       89.91
# 4                    Action, Shooter                       58.76
# ...                              ...                         ...
# 62007               Adventure, Indie                       77.78
# 62008                      Adventure                       50.00
# 62009             Simulation, Casual                       66.67
# 62010                          Indie                       88.24
# 62011                  Casual, Indie                      100.00
#
# [62012 rows x 9 columns]

# %%
df_combinado.sort_values('initialprice')
# Out:
#          appid                               name positive negative  \
# 0          730   Counter-Strike: Global Offensive  7642084  1173003
# 12653  1090760                   Distant Kingdoms      132      172
# 46395  2449180                 环形杀手 Circle Killer        3        2
# 12671  1132880                        The Pilgrim      132        7
# 12674   358420        Xenophage: Alien Bloodsport        7       42
# ...        ...                                ...      ...      ...
# 48790   253670              Aartform Curvy 3D 3.0       32       13
# 34677  2936160                       Pyramid Game        9       13
# 33394  3013840                          True Love        3        1
# 52061  1200520  Ascent Free-Roaming VR Experience        6        1
# 57949  2499620                  The Leverage Game        1        0
#
#           owners  initialprice  \
# 0      150000000          0.00
# 12653      35000          0.00
# 46395      10000          0.00
# 12671      35000          0.00
# 12674      35000          0.00
# ...          ...           ...
# 48790      10000        299.90
# 34677      10000        484.45
# 33394      10000        500.00
# 52061      10000        999.00
# 57949      10000        999.98
#
#                                         background_image  \
# 0      https://media.rawg.io/media/games/736/73619bd3...
# 12653  https://media.rawg.io/media/screenshots/dc4/dc...
# 46395  https://media.rawg.io/media/screenshots/367/36...
# 12671  https://media.rawg.io/media/screenshots/65f/65...
# 12674  https://media.rawg.io/media/screenshots/044/04...
# ...                                                  ...
# 48790  https://media.rawg.io/media/screenshots/0b9/0b...
# 34677  https://media.rawg.io/media/screenshots/aa5/aa...
# 33394  https://media.rawg.io/media/games/385/3851ab32...
# 52061  https://media.rawg.io/media/screenshots/86a/86...
# 57949  https://media.rawg.io/media/screenshots/068/06...
#
#                                                  genres  \
# 0                                               Shooter
# 12653                       Strategy, Simulation, Indie
# 46395     Action, Adventure, RPG, Racing, Casual, Indie
# 12671                                             Indie
# 12674                          Action, Arcade, Fighting
# ...                                                 ...
# 48790                                              None
# 34677  Simulation, Casual, Massively Multiplayer, Indie
# 33394                  Action, Adventure, Casual, Indie
# 52061                                            Action
# 57949                                 Simulation, Indie
#
#        porcentaje_votos_positivos rango_precio
# 0                           86.69          NaN
# 12653                       43.42          NaN
# 46395                       60.00          NaN
# 12671                       94.96          NaN
# 12674                       14.29          NaN
# ...                           ...          ...
# 48790                       71.11          NaN
# 34677                       40.91          NaN
# 33394                       75.00          NaN
# 52061                       85.71          NaN
# 57949                      100.00          NaN
#
# [62012 rows x 10 columns]

# %% [markdown]
# # Análisis de Datos - Gráficas
#
# Análisis exploratorio del dataset combinado de juegos de Steam

# %%
# Preparar datos: Separar los géneros en columnas individuales
df_combinado_generos = pd.get_dummies(df_combinado['genres'].str.split(', ').explode()).groupby(level=0).sum()
df_combinado_con_generos = pd.concat([df_combinado, df_combinado_generos], axis=1)

print(f"Géneros encontrados: {list(df_combinado_generos.columns)}")
print(f"Shape del DataFrame con géneros: {df_combinado_con_generos.shape}")
# Out:
# Géneros encontrados: ['Action', 'Adventure', 'Arcade', 'Board Games', 'Card', 'Casual', 'Educational', 'Family', 'Fighting', 'Indie', 'Massively Multiplayer', 'Platformer', 'Puzzle', 'RPG', 'Racing', 'Shooter', 'Simulation', 'Sports', 'Strategy']
# Shape del DataFrame con géneros: (62012, 28)

# %%
# GRÁFICA 1: Géneros vs Porcentaje de Votos Positivos
# Calcular el promedio de votos positivos por género

generos_columnas = df_combinado_generos.columns
promedios_por_genero = []

for genero in generos_columnas:
    juegos_del_genero = df_combinado_con_generos[df_combinado_con_generos[genero] == 1]
    promedio = juegos_del_genero['porcentaje_votos_positivos'].mean()
    promedios_por_genero.append(promedio)

df_generos_analisis = pd.DataFrame({
    'Género': generos_columnas,
    'Promedio_Votos_Positivos': promedios_por_genero
}).sort_values('Promedio_Votos_Positivos', ascending=False)

# Crear la gráfica
plt.figure(figsize=(14, 6))
plt.barh(df_generos_analisis['Género'], df_generos_analisis['Promedio_Votos_Positivos'], color='steelblue')
plt.xlabel('Porcentaje Promedio de Votos Positivos (%)', fontsize=12)
plt.ylabel('Género', fontsize=12)
plt.title('Porcentaje Promedio de Votos Positivos por Género', fontsize=14, fontweight='bold')
plt.xlim(0, 100)
plt.grid(axis='x', alpha=0.3)

# Añadir valores en las barras
for i, v in enumerate(df_generos_analisis['Promedio_Votos_Positivos']):
    plt.text(v + 1, i, f'{v:.1f}%', va='center', fontsize=9)

plt.tight_layout()
plt.show()

print("\nEstadísticas por Género:")
print(df_generos_analisis.to_string(index=False))
# Out:
# Estadísticas por Género:
#                Género  Promedio_Votos_Positivos
#                Family                 82.777686
#            Platformer                 82.601406
#                Puzzle                 82.445733
#           Educational                 78.986238
#               Shooter                 78.263505
#                Arcade                 77.901041
#              Fighting                 77.618957
#                Casual                 77.486869
#                 Indie                 77.237308
#             Adventure                 76.514270
#                  Card                 75.945283
#                Action                 75.747949
#                   RPG                 75.073268
#           Board Games                 74.715339
#              Strategy                 74.570406
#                Racing                 73.509233
#                Sports                 72.546153
#            Simulation                 72.380434
# Massively Multiplayer                 63.190208

# %%
# GRÁFICA 2: Owners vs Porcentaje de Votos Positivos
# Gráfico de dispersión con línea de tendencia

plt.figure(figsize=(12, 6))

# Scatter plot
plt.scatter(df_combinado['owners'], df_combinado['porcentaje_votos_positivos'], 
            alpha=0.5, s=50, c='steelblue', edgecolors='black', linewidth=0.5)

# Línea de tendencia
z = np.polyfit(df_combinado['owners'], df_combinado['porcentaje_votos_positivos'], 1)
p = np.poly1d(z)
plt.plot(df_combinado['owners'].sort_values(), p(df_combinado['owners'].sort_values()), 
         "r--", linewidth=2, label=f'Tendencia: y={z[0]:.2e}x+{z[1]:.2f}')

plt.xlabel('Número de Propietarios (Owners)', fontsize=12)
plt.ylabel('Porcentaje de Votos Positivos (%)', fontsize=12)
plt.title('Relación entre Número de Propietarios y Votos Positivos', fontsize=14, fontweight='bold')
plt.xscale('log')  # Escala logarítmica para mejor visualización
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# Calcular correlación
correlacion = df_combinado[['owners', 'porcentaje_votos_positivos']].corr().iloc[0, 1]
print(f"\nCoeficiente de correlación: {correlacion:.4f}")
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[22], line 11
#       7 plt.scatter(df_combinado['owners'], df_combinado['porcentaje_votos_positivos'],
#       8             alpha=0.5, s=50, c='steelblue', edgecolors='black', linewidth=0.5)
#      10 # Línea de tendencia
# ---> 11 z = np.polyfit(df_combinado['owners'], df_combinado['porcentaje_votos_positivos'], 1)
#      12 p = np.poly1d(z)
#      13 plt.plot(df_combinado['owners'].sort_values(), p(df_combinado['owners'].sort_values()),
#      14          "r--", linewidth=2, label=f'Tendencia: y={z[0]:.2e}x+{z[1]:.2f}')
#
# File c:\Users\Metal\anaconda3\Lib\site-packages\numpy\lib\_polynomial_impl.py:675, in polyfit(x, y, deg, rcond, full, w, cov)
#     673 scale = NX.sqrt((lhs * lhs).sum(axis=0))
#     674 lhs /= scale
# --> 675 c, resids, rank, s = lstsq(lhs, rhs, rcond)
#     676 c = (c.T / scale).T  # broadcast scale coefficients
#     678 # warn on rank reduction, which indicates an ill conditioned matrix
#
# File c:\Users\Metal\anaconda3\Lib\site-packages\numpy\linalg\_linalg.py:2564, in lstsq(a, b, rcond)
#    2560     b = zeros(b.shape[:-2] + (m, n_rhs + 1), dtype=b.dtype)
#    2562 with errstate(call=_raise_linalgerror_lstsq, invalid='call',
#    2563               over='ignore', divide='ignore', under='ignore'):
# -> 2564     x, resids, rank, s = _umath_linalg.lstsq(a, b, rcond,
#    2565                                              signature=signature)
#    2566 if m == 0:
#    2567     x[...] = 0
#
# File c:\Users\Metal\anaconda3\Lib\site-packages\numpy\linalg\_linalg.py:175, in _raise_linalgerror_lstsq(err, flag)
#     174 def _raise_linalgerror_lstsq(err, flag):
# --> 175     raise LinAlgError("SVD did not converge in Linear Least Squares")
#
# LinAlgError: SVD did not converge in Linear Least Squares

# %%
# GRÁFICA 3: Precio Inicial vs Owners
# Gráfico de dispersión

plt.figure(figsize=(12, 6))

# Scatter plot con gradiente de color basado en votos positivos
scatter = plt.scatter(df_combinado['initialprice'], df_combinado['owners'], 
                     c=df_combinado['porcentaje_votos_positivos'], 
                     cmap='RdYlGn', alpha=0.6, s=50, edgecolors='black', linewidth=0.5)

plt.xlabel('Precio Inicial (€)', fontsize=12)
plt.ylabel('Número de Propietarios (Owners)', fontsize=12)
plt.title('Relación entre Precio Inicial y Número de Propietarios', fontsize=14, fontweight='bold')
plt.yscale('log')  # Escala logarítmica para owners
plt.grid(True, alpha=0.3)

# Barra de color
cbar = plt.colorbar(scatter)
cbar.set_label('% Votos Positivos', rotation=270, labelpad=20)

plt.tight_layout()
plt.show()

# Correlación
correlacion = df_combinado[['initialprice', 'owners']].corr().iloc[0, 1]
print(f"\nCoeficiente de correlación Precio-Owners: {correlacion:.4f}")

# Estadísticas por rangos de precio
df_combinado['rango_precio'] = pd.cut(df_combinado['initialprice'], 
                                       bins=[0, 5, 10, 20, 50, 100],
                                       labels=['0-5€', '5-10€', '10-20€', '20-50€', '>50€'])

stats_precio = df_combinado.groupby('rango_precio')['owners'].agg(['mean', 'median', 'count'])
print("\nEstadísticas de Owners por Rango de Precio:")
print(stats_precio)
# Out:
# Coeficiente de correlación Precio-Owners: 0.0524
#
# Estadísticas de Owners por Rango de Precio:
#                       mean   median  count
# rango_precio
# 0-5€          4.205392e+04  10000.0  24962
# 5-10€         7.941623e+04  10000.0  14963
# 10-20€        1.787925e+05  10000.0  11060
# 20-50€        4.751363e+05  35000.0   3449
# >50€          1.479944e+06  35000.0    360
# C:\Users\Metal\AppData\Local\Temp\ipykernel_42572\2348105714.py:33: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   stats_precio = df_combinado.groupby('rango_precio')['owners'].agg(['mean', 'median', 'count'])

# %%
# GRÁFICA 4: Géneros vs Owners
# Calcular el promedio de owners por género

promedios_owners_por_genero = []

for genero in generos_columnas:
    juegos_del_genero = df_combinado_con_generos[df_combinado_con_generos[genero] == 1]
    promedio = juegos_del_genero['owners'].mean()
    promedios_owners_por_genero.append(promedio)

df_generos_owners = pd.DataFrame({
    'Género': generos_columnas,
    'Promedio_Owners': promedios_owners_por_genero
}).sort_values('Promedio_Owners', ascending=False)

# Crear la gráfica
plt.figure(figsize=(14, 6))
colors = plt.cm.viridis(np.linspace(0.3, 0.9, len(df_generos_owners)))
plt.barh(df_generos_owners['Género'], df_generos_owners['Promedio_Owners'], color=colors)
plt.xlabel('Promedio de Propietarios (Owners)', fontsize=12)
plt.ylabel('Género', fontsize=12)
plt.title('Promedio de Propietarios por Género', fontsize=14, fontweight='bold')
plt.grid(axis='x', alpha=0.3)

# Añadir valores en las barras
for i, v in enumerate(df_generos_owners['Promedio_Owners']):
    plt.text(v + v*0.02, i, f'{v:,.0f}', va='center', fontsize=9)

plt.tight_layout()
plt.show()

print("\nEstadísticas de Owners por Género:")
print(df_generos_owners.to_string(index=False))
# Out:
# Estadísticas de Owners por Género:
#                Género  Promedio_Owners
#               Shooter     1.822612e+06
#              Fighting     7.073620e+05
# Massively Multiplayer     6.921534e+05
#            Platformer     3.587518e+05
#                  Card     2.694340e+05
#                Family     2.414192e+05
#                Action     2.051191e+05
#                Arcade     2.025670e+05
#                   RPG     1.929533e+05
#           Board Games     1.715063e+05
#                Puzzle     1.680356e+05
#           Educational     1.468720e+05
#                Sports     1.468523e+05
#            Simulation     1.290756e+05
#              Strategy     1.222904e+05
#                Racing     1.166021e+05
#             Adventure     1.113690e+05
#                 Indie     8.884171e+04
#                Casual     6.290836e+04

# %%
# GRÁFICA 3: Precio Inicial vs Owners
# Gráfico de dispersión

plt.figure(figsize=(12, 6))

# Scatter plot con gradiente de color basado en votos positivos
scatter = plt.scatter(df_combinado['porcentaje_votos_positivos'], df_combinado['owners'], 
                     c=df_combinado['porcentaje_votos_positivos'], 
                     cmap='RdYlGn', alpha=0.6, s=50, edgecolors='black', linewidth=0.5)

plt.xlabel('Porcentaje de votos positivos', fontsize=12)
plt.ylabel('Número de Propietarios (Owners)', fontsize=12)
plt.title('Relación entre Porcentaje de votos positivos y Número de Propietarios', fontsize=14, fontweight='bold')
plt.yscale('log')  # Escala logarítmica para owners
plt.grid(True, alpha=0.3)

# Barra de color
cbar = plt.colorbar(scatter)
cbar.set_label('% Votos Positivos', rotation=270, labelpad=20)

plt.tight_layout()
plt.show()

# Correlación
correlacion = df_combinado[['porcentaje_votos_positivos', 'owners']].corr().iloc[0, 1]
print(f"\nCoeficiente de correlación Porcentaje de votos positivos-Owners: {correlacion:.4f}")
# Out:
# Coeficiente de correlación Porcentaje de votos positivos-Owners: 0.0231
